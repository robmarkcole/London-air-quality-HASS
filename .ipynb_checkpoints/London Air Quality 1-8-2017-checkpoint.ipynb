# %% [markdown]
# https://www.londonair.org.uk/LondonAir/API/
#
# Docs http://api.erg.kcl.ac.uk/AirQuality/Information/Documentation/pdf
#
# Pollutants http://api.erg.kcl.ac.uk/AirQuality/Information/Species/Json

# %%
import requests
import json
import pprint

def print_json(json_data):
    pprint.PrettyPrinter().pprint(json_data)

# %% [markdown]
# # HASS class

# %%
LOCATIONS = 'Locations'
URL = 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/GroupName=London/Json'
#SCAN_INTERVAL = timedelta(minutes=15)

# Remove authorities without any Sites ['Hounslow', 'Bromley', 'Waltham Forest', 'Barnet', 'Newham']
AUTHORITIES = [
    'Barking and Dagenham',
    'Bexley',
    'Brent',
    'Camden',
    'City of London',
    'Croydon',
    'Ealing',
    'Enfield',
    'Greenwich',
    'Hackney',
    'Hammersmith and Fulham',
    'Haringey',
    'Harrow',
    'Havering',
    'Hillingdon',
    'Islington',
    'Kensington and Chelsea',
    'Kingston',
    'Lambeth',
    'Lewisham',
    'Merton',
    'Redbridge',
    'Richmond',
    'Southwark',
    'Sutton',
    'Tower Hamlets',
    'Wandsworth',
    'Westminster']

CONFIG = {LOCATIONS: ['Merton','Richmond',]}  # A list of required locations

# %%
def parse_api_response(response):
    """Take in the API response. API can return dict or list of data so need to check. """
    data = dict.fromkeys(AUTHORITIES)     # Holds all data
    for authority in AUTHORITIES:
        for entry in response['HourlyAirQualityIndex']['LocalAuthority']:   # Loop over entries
            if entry['@LocalAuthorityName'] == authority:
                authority_data = []
                
                if isinstance(entry['Site'], dict):
                    entry_sites_data = [entry['Site']]  
                else:
                    entry_sites_data = entry['Site']  
                
                for site in entry_sites_data:
                    site_data = {}
                    species_data = []
                    
                    site_data['Updated']   = site['@BulletinDate']
                    site_data['Latitude']  = site['@Latitude']
                    site_data['Longitude'] = site['@Longitude']
                    site_data['Site_code'] = site['@SiteCode']
                    site_data['Site_name'] = site['@SiteName'].split("-")[-1].lstrip()  
                    site_data['Site_type'] = site['@SiteType']
                    
                    if isinstance(site['Species'], dict):
                        species_data = [site['Species']]  
                    else:
                        species_data = site['Species'] 
                    
                    parsed_species_data = []
                    quality_list = []
                    for species in species_data:                     
                        if species['@AirQualityBand'] != 'No data': 
                            species_dict = {}
                            species_dict['Description'] = species['@SpeciesDescription']
                            species_dict['Code'] = species['@SpeciesCode']
                            species_dict['Quality'] = species['@AirQualityBand']
                            species_dict['Index'] = species['@AirQualityIndex']
                            species_dict['Summary'] = species_dict['Code'] + ' is ' + species_dict['Quality']
                            parsed_species_data.append(species_dict)
                            quality_list.append(species_dict['Quality'])
                    
                    if not parsed_species_data:      # if no valid species data
                        parsed_species_data.append('No_species_data')
                    site_data['Pollutants'] = parsed_species_data
                    
                    if quality_list:
                        site_data['Pollutants_status'] = max(set(quality_list), key=quality_list.count)
                        site_data['Number_of_pollutants'] = len(quality_list)
                    else:
                        site_data['Pollutants_status'] = 'No_species_data' 
                        site_data['Number_of_pollutants'] = 0  
                        
                    authority_data.append(site_data)
                    
                data[authority] = authority_data

    return data

# %%
class APIData(object):
    """Get the latest data for all authorities."""

    def __init__(self):
        """Initialize the AirData object."""
        self.data = None
       
    # Update only once in scan interval.
    #@Throttle(SCAN_INTERVAL)
    def update(self):
        """Get the latest data from TFL."""
        response = requests.get(URL)
        if response.status_code != 200:
            _LOGGER.warning("Invalid response from API")
        else:
            self.data = parse_api_response(response.json())

# %%
class AirSensor():   # Entity
    """Single authority air sensor"""

    ICON = 'mdi:cloud-outline'

    def __init__(self, name, APIdata):
        """Initialize the sensor."""
        self._name = name
        self._APIdata = APIdata
        self._site_data = None
        self._state = None
        self._updated = None
        
    @property
    def name(self):
        """Return the name of the sensor."""
        return self._name

    @property
    def state(self):
        """Return the state of the sensor."""
        return self._state
    
    @property
    def site_data(self):
        """Return the dict of sites data."""
        return self._site_data

    @property
    def icon(self):
        """Icon to use in the frontend, if any."""
        return self.ICON

    @property
    def device_state_attributes(self):
        """Return other details about the sensor state."""
        attrs = {}
        attrs['Updated'] = self._updated
        attrs['Sites'] = len(self._site_data)
        return attrs

    def update(self):
        """Update the sensor."""
        self._APIdata.update()
        self._site_data = self._APIdata.data[self._name]
        self._updated = self._site_data[0]['Updated']     
        sites_status = []
        for site in self._site_data:
            if site['Pollutants_status'] != 'No_species_data':
                sites_status.append(site['Pollutants_status'])  
        if sites_status:
            self._state = max(set(sites_status), key=sites_status.count)
        else:
            self._state = 'No_species_data'

# %%
def setup_platform(config):
    """Set up the Tube sensor."""
    data = APIData()
    data.update()
    sensors = []
    for name in config[LOCATIONS]:
        sensors.append(AirSensor(name, data))
    return sensors

# %%
CONFIG = {LOCATIONS: AUTHORITIES}   # check with all areas - works
my_sensors = setup_platform(CONFIG)

# %%
for sensor in my_sensors:
    sensor.update()

# %%
for sensor in my_sensors:
    print_json(sensor.site_data[0])
# Out:
# {'Latitude': '51.563752',
#  'Longitude': '0.177891',
#  'Number_of_pollutants': 2,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'SO2',
#                  'Description': 'Sulphur Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'SO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'BG1',
#  'Site_name': 'Rush Green',
#  'Site_type': 'Suburban',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.4946486813055',
#  'Longitude': '0.137279111232178',
#  'Number_of_pollutants': 3,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'O3',
#                  'Description': 'Ozone',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'O3 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'BQ7',
#  'Site_name': 'Belvedere West',
#  'Site_type': 'Urban Background',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.552476',
#  'Longitude': '-0.258089',
#  'Number_of_pollutants': 3,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'O3',
#                  'Description': 'Ozone',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'O3 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'BT4',
#  'Site_name': 'Ikea',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.522287',
#  'Longitude': '-0.125848',
#  'Number_of_pollutants': 4,
#  'Pollutants': [{'Code': 'O3',
#                  'Description': 'Ozone',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'O3 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'},
#                 {'Code': 'PM25',
#                  'Description': 'PM2.5 Particulate',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'PM25 is Low'},
#                 {'Code': 'SO2',
#                  'Description': 'Sulphur Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'SO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'BL0',
#  'Site_name': 'Bloomsbury',
#  'Site_type': 'Urban Background',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.5145253362314',
#  'Longitude': '-0.104515626337876',
#  'Number_of_pollutants': 1,
#  'Pollutants': [{'Code': 'PM25',
#                  'Description': 'PM2.5 Particulate',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'PM25 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'CT2',
#  'Site_name': 'Farringdon Street',
#  'Site_type': 'Kerbside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.411349',
#  'Longitude': '-0.12311',
#  'Number_of_pollutants': 1,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'CR5',
#  'Site_name': 'Norbury',
#  'Site_type': 'Kerbside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.53085',
#  'Longitude': '-0.292488',
#  'Number_of_pollutants': 2,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'EA6',
#  'Site_name': 'Hanger Lane Gyratory',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.6450367266602',
#  'Longitude': '-0.0661800662229116',
#  'Number_of_pollutants': 0,
#  'Pollutants': ['No_species_data'],
#  'Pollutants_status': 'No_species_data',
#  'Site_code': 'EN1',
#  'Site_name': 'Bush Hill Park',
#  'Site_type': 'Suburban',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.490532',
#  'Longitude': '0.074003',
#  'Number_of_pollutants': 3,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'},
#                 {'Code': 'PM25',
#                  'Description': 'PM2.5 Particulate',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'PM25 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'GN0',
#  'Site_name': 'A206 Burrage Grove',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.526454',
#  'Longitude': '-0.08491',
#  'Number_of_pollutants': 3,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'O3',
#                  'Description': 'Ozone',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'O3 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'HK6',
#  'Site_name': 'Old Street',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.5045625671557',
#  'Longitude': '-0.224670007031603',
#  'Number_of_pollutants': 2,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'HF4',
#  'Site_name': 'Shepherds Bush',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.599302',
#  'Longitude': '-0.068218',
#  'Number_of_pollutants': 1,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'HG1',
#  'Site_name': 'Haringey Town Hall',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.617327',
#  'Longitude': '-0.298775',
#  'Number_of_pollutants': 0,
#  'Pollutants': ['No_species_data'],
#  'Pollutants_status': 'No_species_data',
#  'Site_code': 'HR1',
#  'Site_name': 'Stanmore',
#  'Site_type': 'Urban Background',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.520787459334',
#  'Longitude': '0.205460705694044',
#  'Number_of_pollutants': 1,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'HV1',
#  'Site_name': 'Rainham',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.496309',
#  'Longitude': '-0.460826',
#  'Number_of_pollutants': 2,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'O3',
#                  'Description': 'Ozone',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'O3 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'HI0',
#  'Site_name': 'Keats Way',
#  'Site_type': 'Suburban',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.555378',
#  'Longitude': '-0.116146',
#  'Number_of_pollutants': 2,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'IS2',
#  'Site_name': 'Holloway Road',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.5210467476039',
#  'Longitude': '-0.213492139585065',
#  'Number_of_pollutants': 4,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'O3',
#                  'Description': 'Ozone',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'O3 is Low'},
#                 {'Code': 'PM25',
#                  'Description': 'PM2.5 Particulate',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'PM25 is Low'},
#                 {'Code': 'SO2',
#                  'Description': 'Sulphur Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'SO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'KC1',
#  'Site_name': 'North Ken',
#  'Site_type': 'Urban Background',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.379312',
#  'Longitude': '-0.281259',
#  'Number_of_pollutants': 2,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'KT4',
#  'Site_name': 'Tolworth Broadway',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.464113541162',
#  'Longitude': '-0.11458102695123',
#  'Number_of_pollutants': 2,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'LB4',
#  'Site_name': 'Brixton Road',
#  'Site_type': 'Kerbside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.445468',
#  'Longitude': '-0.020266',
#  'Number_of_pollutants': 0,
#  'Pollutants': ['No_species_data'],
#  'Pollutants_status': 'No_species_data',
#  'Site_code': 'LW1',
#  'Site_name': 'Catford',
#  'Site_type': 'Urban Background',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.4161384794862',
#  'Longitude': '-0.192230805042824',
#  'Number_of_pollutants': 1,
#  'Pollutants': [{'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'ME2',
#  'Site_name': 'Merton Road',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.57661',
#  'Longitude': '0.030858',
#  'Number_of_pollutants': 2,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'RB4',
#  'Site_name': 'Gardner Close',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.4531422511004',
#  'Longitude': '-0.341218138106469',
#  'Number_of_pollutants': 0,
#  'Pollutants': ['No_species_data'],
#  'Pollutants_status': 'No_species_data',
#  'Site_code': 'RHG',
#  'Site_name': 'Chertsey Road',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.4804994936467',
#  'Longitude': '-0.0595528932573422',
#  'Number_of_pollutants': 1,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'SK5',
#  'Site_name': 'A2 Old Kent Road',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.3586596124998',
#  'Longitude': '-0.149723946604927',
#  'Number_of_pollutants': 1,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'ST4',
#  'Site_name': 'Wallington',
#  'Site_type': 'Kerbside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.5225294860844',
#  'Longitude': '-0.0421550991900347',
#  'Number_of_pollutants': 1,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'TH2',
#  'Site_name': 'Mile End Road',
#  'Site_type': 'Roadside',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.456962',
#  'Longitude': '-0.191074',
#  'Number_of_pollutants': 1,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'WA2',
#  'Site_name': 'Wandsworth Town Hall',
#  'Site_type': 'Urban Background',
#  'Updated': '2017-08-02 17:00:00'}
# {'Latitude': '51.52254',
#  'Longitude': '-0.15459',
#  'Number_of_pollutants': 4,
#  'Pollutants': [{'Code': 'NO2',
#                  'Description': 'Nitrogen Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'NO2 is Low'},
#                 {'Code': 'O3',
#                  'Description': 'Ozone',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'O3 is Low'},
#                 {'Code': 'PM10',
#                  'Description': 'PM10 Particulate',
#                  'Index': '2',
#                  'Quality': 'Low',
#                  'Summary': 'PM10 is Low'},
#                 {'Code': 'SO2',
#                  'Description': 'Sulphur Dioxide',
#                  'Index': '1',
#                  'Quality': 'Low',
#                  'Summary': 'SO2 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'MY1',
#  'Site_name': 'Marylebone Road',
#  'Site_type': 'Kerbside',
#  'Updated': '2017-08-02 17:00:00'}

# %%
my_sensors[1].name
# Out:
# 'Bexley'

# %%
my_sensors[1].state
# Out:
# 'Low'

# %%
my_sensors[1]._updated
# Out:
# '2017-08-02 17:00:00'

# %%
my_sensors[1].device_state_attributes
# Out:
# {'Sites': 8, 'Updated': '2017-08-02 17:00:00'}

# %%
my_sensors[1].site_data[0]#['Pollutants'][0]['Summary']
# Out:
# {'Latitude': '51.4946486813055',
#  'Longitude': '0.137279111232178',
#  'Number_of_pollutants': 3,
#  'Pollutants': [{'Code': 'NO2',
#    'Description': 'Nitrogen Dioxide',
#    'Index': '1',
#    'Quality': 'Low',
#    'Summary': 'NO2 is Low'},
#   {'Code': 'O3',
#    'Description': 'Ozone',
#    'Index': '2',
#    'Quality': 'Low',
#    'Summary': 'O3 is Low'},
#   {'Code': 'PM10',
#    'Description': 'PM10 Particulate',
#    'Index': '1',
#    'Quality': 'Low',
#    'Summary': 'PM10 is Low'}],
#  'Pollutants_status': 'Low',
#  'Site_code': 'BQ7',
#  'Site_name': 'Belvedere West',
#  'Site_type': 'Urban Background',
#  'Updated': '2017-08-02 17:00:00'}
