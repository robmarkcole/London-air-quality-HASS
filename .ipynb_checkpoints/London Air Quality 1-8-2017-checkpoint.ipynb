# %% [markdown]
# https://www.londonair.org.uk/LondonAir/API/
#
# Docs http://api.erg.kcl.ac.uk/AirQuality/Information/Documentation/pdf
#
# Pollutants http://api.erg.kcl.ac.uk/AirQuality/Information/Species/Json

# %%
import requests
import json
import pprint

def print_json(json_data):
    pprint.PrettyPrinter().pprint(json_data)

# %% [markdown]
# # HASS class

# %%
LOCATIONS = 'Locations'
URL = 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/GroupName=London/Json'
SCAN_INTERVAL = timedelta(minutes=15)

# Remove authorities without any Sites ['Hounslow', 'Bromley', 'Waltham Forest', 'Barnet', 'Newham']
AUTHORITIES = [
    'Barking and Dagenham',
    'Bexley',
    'Brent',
    'Camden',
    'City of London',
    'Croydon',
    'Ealing',
    'Enfield',
    'Greenwich',
    'Hackney',
    'Hammersmith and Fulham',
    'Haringey',
    'Harrow',
    'Havering',
    'Hillingdon',
    'Islington',
    'Kensington and Chelsea',
    'Kingston',
    'Lambeth',
    'Lewisham',
    'Merton',
    'Redbridge',
    'Richmond',
    'Southwark',
    'Sutton',
    'Tower Hamlets',
    'Wandsworth',
    'Westminster']

CONFIG = {LOCATIONS: ['Merton','Richmond',]}  # A list of required locations

# %%
def parse_api_response(response):
    """Take in the API response. API can return dict or list of data so need to check. """
    data = dict.fromkeys(AUTHORITIES)     # Holds all data
    for authority in AUTHORITIES:
        for entry in response['HourlyAirQualityIndex']['LocalAuthority']:   # Loop over entries
            if entry['@LocalAuthorityName'] == authority:
                authority_data = []
                
                if isinstance(entry['Site'], dict):
                    entry_sites_data = [entry['Site']]  
                else:
                    entry_sites_data = entry['Site']  
                
                for site in entry_sites_data:
                    site_data = {}
                    species_data = []
                    
                    site_data['Updated']   = site['@BulletinDate']
                    site_data['Latitude']  = site['@Latitude']
                    site_data['Longitude'] = site['@Longitude']
                    site_data['Site_code'] = site['@SiteCode']
                    site_data['Site_name'] = site['@SiteName'].split("-")[-1].lstrip()  
                    site_data['Site_type'] = site['@SiteType']
                    
                    if isinstance(site['Species'], dict):
                        species_data = [site['Species']]  
                    else:
                        species_data = site['Species'] 
                    
                    parsed_species_data = []
                    quality_list = []
                    for species in species_data:                     
                        if species['@AirQualityBand'] != 'No data': 
                            species_dict = {}
                            species_dict['Description'] = species['@SpeciesDescription']
                            species_dict['Code'] = species['@SpeciesCode']
                            species_dict['Quality'] = species['@AirQualityBand']
                            species_dict['Index'] = species['@AirQualityIndex']
                            species_dict['Summary'] = species_dict['Code'] + ' is ' + species_dict['Quality']
                            parsed_species_data.append(species_dict)
                            quality_list.append(species_dict['Quality'])
                    
                    if not parsed_species_data:      # if no valid species data
                        parsed_species_data.append('No_species_data')
                    site_data['Pollutants'] = parsed_species_data
                    
                    if quality_list:
                        site_data['Pollutants_status'] = max(set(quality_list), key=quality_list.count)
                        site_data['Number_of_pollutants'] = len(quality_list)
                    else:
                        site_data['Pollutants_status'] = 'No_species_data' 
                        site_data['Number_of_pollutants'] = 0  
                        
                    authority_data.append(site_data)
                    
                data[authority] = authority_data

    return data

# %%
response = requests.get(URL).json()
my_data = parse_api_response(response)

# %%
my_data.keys()
# Out:
# dict_keys(['Hackney', 'Camden', 'Greenwich', 'Tower Hamlets', 'Lambeth', 'Havering', 'Kingston', 'Southwark', 'Kensington and Chelsea', 'Hillingdon', 'Sutton', 'Redbridge', 'Lewisham', 'Croydon', 'Richmond', 'Bexley', 'Haringey', 'Hammersmith and Fulham', 'Wandsworth', 'Brent', 'City of London', 'Barking and Dagenham', 'Enfield', 'Westminster', 'Harrow', 'Islington', 'Ealing', 'Merton'])

# %%
my_data['Merton']
# Out:
# [{'Latitude': '51.4161384794862',
#   'Longitude': '-0.192230805042824',
#   'Number_of_pollutants': 1,
#   'Pollutants': [{'Code': 'PM10',
#     'Description': 'PM10 Particulate',
#     'Index': '1',
#     'Quality': 'Low',
#     'Summary': 'PM10 is Low'}],
#   'Pollutants_status': 'Low',
#   'Site_code': 'ME2',
#   'Site_name': 'Merton Road',
#   'Site_type': 'Roadside',
#   'Updated': '2017-08-01 04:00:00'},
#  {'Latitude': '51.40162',
#   'Longitude': '-0.19589212',
#   'Number_of_pollutants': 1,
#   'Pollutants': [{'Code': 'NO2',
#     'Description': 'Nitrogen Dioxide',
#     'Index': '1',
#     'Quality': 'Low',
#     'Summary': 'NO2 is Low'}],
#   'Pollutants_status': 'Low',
#   'Site_code': 'ME9',
#   'Site_name': 'Morden Civic Centre 2',
#   'Site_type': 'Roadside',
#   'Updated': '2017-08-01 04:00:00'}]

# %%
print_json(my_data)
# Out:
# {'Barking and Dagenham': [{'Latitude': '51.563752',
#                            'Longitude': '0.177891',
#                            'Number_of_pollutants': 2,
#                            'Pollutants': [{'Code': 'NO2',
#                                            'Description': 'Nitrogen Dioxide',
#                                            'Index': '1',
#                                            'Quality': 'Low',
#                                            'Summary': 'NO2 is Low'},
#                                           {'Code': 'SO2',
#                                            'Description': 'Sulphur Dioxide',
#                                            'Index': '1',
#                                            'Quality': 'Low',
#                                            'Summary': 'SO2 is Low'}],
#                            'Pollutants_status': 'Low',
#                            'Site_code': 'BG1',
#                            'Site_name': 'Rush Green',
#                            'Site_type': 'Suburban',
#                            'Updated': '2017-08-01 04:00:00'},
#                           {'Latitude': '51.529389',
#                            'Longitude': '0.132857',
#                            'Number_of_pollutants': 2,
#                            'Pollutants': [{'Code': 'NO2',
#                                            'Description': 'Nitrogen Dioxide',
#                                            'Index': '1',
#                                            'Quality': 'Low',
#                                            'Summary': 'NO2 is Low'},
#                                           {'Code': 'PM10',
#                                            'Description': 'PM10 Particulate',
#                                            'Index': '1',
#                                            'Quality': 'Low',
#                                            'Summary': 'PM10 is Low'}],
#                            'Pollutants_status': 'Low',
#                            'Site_code': 'BG2',
#                            'Site_name': 'Scrattons Farm',
#                            'Site_type': 'Suburban',
#                            'Updated': '2017-08-01 04:00:00'}],
#  'Bexley': [{'Latitude': '51.4946486813055',
#              'Longitude': '0.137279111232178',
#              'Number_of_pollutants': 3,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low',
#                              'Summary': 'O3 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'BQ7',
#              'Site_name': 'Belvedere West',
#              'Site_type': 'Urban Background',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.4946486813055',
#              'Longitude': '0.137279111232178',
#              'Number_of_pollutants': 0,
#              'Pollutants': ['No_species_data'],
#              'Pollutants_status': 'No_species_data',
#              'Site_code': 'BQ8',
#              'Site_name': 'Belvedere West FDMS',
#              'Site_type': 'Urban Background',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.4906102082147',
#              'Longitude': '0.158914493927518',
#              'Number_of_pollutants': 1,
#              'Pollutants': [{'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'BX0',
#              'Site_name': 'Belvedere FDMS',
#              'Site_type': 'Suburban',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.4659832746662',
#              'Longitude': '0.184877126994369',
#              'Number_of_pollutants': 3,
#              'Pollutants': [{'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'O3 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'},
#                             {'Code': 'SO2',
#                              'Description': 'Sulphur Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'SO2 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'BX1',
#              'Site_name': 'Slade Green',
#              'Site_type': 'Suburban',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.4906102082147',
#              'Longitude': '0.158914493927518',
#              'Number_of_pollutants': 2,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'BX2',
#              'Site_name': 'Belvedere',
#              'Site_type': 'Suburban',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.4659832746662',
#              'Longitude': '0.184877126994369',
#              'Number_of_pollutants': 1,
#              'Pollutants': [{'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM25 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'BX9',
#              'Site_name': 'Slade Green FDMS',
#              'Site_type': 'Suburban',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.4563',
#              'Longitude': '0.085606',
#              'Number_of_pollutants': 1,
#              'Pollutants': [{'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM25 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'GB0',
#              'Site_name': 'Falconwood FDMS',
#              'Site_type': 'Roadside',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.4563',
#              'Longitude': '0.085606',
#              'Number_of_pollutants': 3,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low',
#                              'Summary': 'O3 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'GB6',
#              'Site_name': 'Falconwood',
#              'Site_type': 'Roadside',
#              'Updated': '2017-08-01 04:00:00'}],
#  'Brent': [{'Latitude': '51.552476',
#             'Longitude': '-0.258089',
#             'Number_of_pollutants': 3,
#             'Pollutants': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low',
#                             'Summary': 'NO2 is Low'},
#                            {'Code': 'O3',
#                             'Description': 'Ozone',
#                             'Index': '1',
#                             'Quality': 'Low',
#                             'Summary': 'O3 is Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low',
#                             'Summary': 'PM10 is Low'}],
#             'Pollutants_status': 'Low',
#             'Site_code': 'BT4',
#             'Site_name': 'Ikea',
#             'Site_type': 'Roadside',
#             'Updated': '2017-08-01 04:00:00'},
#            {'Latitude': '51.552656',
#             'Longitude': '-0.248774',
#             'Number_of_pollutants': 2,
#             'Pollutants': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low',
#                             'Summary': 'NO2 is Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low',
#                             'Summary': 'PM10 is Low'}],
#             'Pollutants_status': 'Low',
#             'Site_code': 'BT5',
#             'Site_name': 'Neasden Lane',
#             'Site_type': 'Industrial',
#             'Updated': '2017-08-01 04:00:00'},
#            {'Latitude': '51.537799',
#             'Longitude': '-0.247793',
#             'Number_of_pollutants': 2,
#             'Pollutants': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low',
#                             'Summary': 'NO2 is Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low',
#                             'Summary': 'PM10 is Low'}],
#             'Pollutants_status': 'Low',
#             'Site_code': 'BT6',
#             'Site_name': 'John Keble Primary School',
#             'Site_type': 'Roadside',
#             'Updated': '2017-08-01 04:00:00'},
#            {'Latitude': '51.5324054617809',
#             'Longitude': '-0.217718908639377',
#             'Number_of_pollutants': 0,
#             'Pollutants': ['No_species_data'],
#             'Pollutants_status': 'No_species_data',
#             'Site_code': 'BT8',
#             'Site_name': 'Ark Franklin Academy',
#             'Site_type': 'Roadside',
#             'Updated': '2017-08-01 04:00:00'}],
#  'Camden': [{'Latitude': '51.522287',
#              'Longitude': '-0.125848',
#              'Number_of_pollutants': 5,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'O3 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM25 is Low'},
#                             {'Code': 'SO2',
#                              'Description': 'Sulphur Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'SO2 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'BL0',
#              'Site_name': 'Bloomsbury',
#              'Site_type': 'Urban Background',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.544219',
#              'Longitude': '-0.175284',
#              'Number_of_pollutants': 3,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM25 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'CD1',
#              'Site_name': 'Swiss Cottage',
#              'Site_type': 'Kerbside',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.5277066194645',
#              'Longitude': '-0.129053205282516',
#              'Number_of_pollutants': 3,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '2',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '2',
#                              'Quality': 'Low',
#                              'Summary': 'PM25 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'CD9',
#              'Site_name': 'Euston Road',
#              'Site_type': 'Roadside',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.5173675146177',
#              'Longitude': '-0.1201947113171',
#              'Number_of_pollutants': 1,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'IM1',
#              'Site_name': 'Holborn (inmidtown)',
#              'Site_type': 'Kerbside',
#              'Updated': '2017-08-01 04:00:00'}],
#  'City of London': [{'Latitude': '51.5145253362314',
#                      'Longitude': '-0.104515626337876',
#                      'Number_of_pollutants': 1,
#                      'Pollutants': [{'Code': 'PM25',
#                                      'Description': 'PM2.5 Particulate',
#                                      'Index': '1',
#                                      'Quality': 'Low',
#                                      'Summary': 'PM25 is Low'}],
#                      'Pollutants_status': 'Low',
#                      'Site_code': 'CT2',
#                      'Site_name': 'Farringdon Street',
#                      'Site_type': 'Kerbside',
#                      'Updated': '2017-08-01 04:00:00'},
#                     {'Latitude': '51.513847178423',
#                      'Longitude': '-0.077765681752',
#                      'Number_of_pollutants': 3,
#                      'Pollutants': [{'Code': 'NO2',
#                                      'Description': 'Nitrogen Dioxide',
#                                      'Index': '1',
#                                      'Quality': 'Low',
#                                      'Summary': 'NO2 is Low'},
#                                     {'Code': 'PM10',
#                                      'Description': 'PM10 Particulate',
#                                      'Index': '2',
#                                      'Quality': 'Low',
#                                      'Summary': 'PM10 is Low'},
#                                     {'Code': 'PM25',
#                                      'Description': 'PM2.5 Particulate',
#                                      'Index': '1',
#                                      'Quality': 'Low',
#                                      'Summary': 'PM25 is Low'}],
#                      'Pollutants_status': 'Low',
#                      'Site_code': 'CT3',
#                      'Site_name': 'Sir John Cass School',
#                      'Site_type': 'Urban Background',
#                      'Updated': '2017-08-01 04:00:00'},
#                     {'Latitude': '51.520225273171',
#                      'Longitude': '-0.0961060474176381',
#                      'Number_of_pollutants': 2,
#                      'Pollutants': [{'Code': 'NO2',
#                                      'Description': 'Nitrogen Dioxide',
#                                      'Index': '1',
#                                      'Quality': 'Low',
#                                      'Summary': 'NO2 is Low'},
#                                     {'Code': 'PM10',
#                                      'Description': 'PM10 Particulate',
#                                      'Index': '1',
#                                      'Quality': 'Low',
#                                      'Summary': 'PM10 is Low'}],
#                      'Pollutants_status': 'Low',
#                      'Site_code': 'CT4',
#                      'Site_name': 'Beech Street',
#                      'Site_type': 'Roadside',
#                      'Updated': '2017-08-01 04:00:00'},
#                     {'Latitude': '51.510499',
#                      'Longitude': '-0.091634',
#                      'Number_of_pollutants': 1,
#                      'Pollutants': [{'Code': 'NO2',
#                                      'Description': 'Nitrogen Dioxide',
#                                      'Index': '1',
#                                      'Quality': 'Low',
#                                      'Summary': 'NO2 is Low'}],
#                      'Pollutants_status': 'Low',
#                      'Site_code': 'CT6',
#                      'Site_name': 'Walbrook Wharf',
#                      'Site_type': 'Roadside',
#                      'Updated': '2017-08-01 04:00:00'},
#                     {'Latitude': '51.5095436853913',
#                      'Longitude': '-0.0873571979556188',
#                      'Number_of_pollutants': 1,
#                      'Pollutants': [{'Code': 'PM10',
#                                      'Description': 'PM10 Particulate',
#                                      'Index': '1',
#                                      'Quality': 'Low',
#                                      'Summary': 'PM10 is Low'}],
#                      'Pollutants_status': 'Low',
#                      'Site_code': 'CT8',
#                      'Site_name': 'Upper Thames Street',
#                      'Site_type': 'Roadside',
#                      'Updated': '2017-08-01 04:00:00'}],
#  'Croydon': [{'Latitude': '51.411349',
#               'Longitude': '-0.12311',
#               'Number_of_pollutants': 1,
#               'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'NO2 is Low'}],
#               'Pollutants_status': 'Low',
#               'Site_code': 'CR5',
#               'Site_name': 'Norbury',
#               'Site_type': 'Kerbside',
#               'Updated': '2017-08-01 04:00:00'},
#              {'Latitude': '51.3622305655403',
#               'Longitude': '-0.117604507351392',
#               'Number_of_pollutants': 1,
#               'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'NO2 is Low'}],
#               'Pollutants_status': 'Low',
#               'Site_code': 'CR7',
#               'Site_name': 'Purley Way A23',
#               'Site_type': 'Roadside',
#               'Updated': '2017-08-01 04:00:00'},
#              {'Latitude': '51.410039',
#               'Longitude': '-0.127523',
#               'Number_of_pollutants': 0,
#               'Pollutants': ['No_species_data'],
#               'Pollutants_status': 'No_species_data',
#               'Site_code': 'CR8',
#               'Site_name': 'Norbury Manor',
#               'Site_type': 'Urban Background',
#               'Updated': '2017-08-01 04:00:00'},
#              {'Latitude': '51.3739530635378',
#               'Longitude': '-0.0967638468323854',
#               'Number_of_pollutants': 1,
#               'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'NO2 is Low'}],
#               'Pollutants_status': 'Low',
#               'Site_code': 'CR9',
#               'Site_name': 'Park Lane',
#               'Site_type': 'Roadside',
#               'Updated': '2017-08-01 04:00:00'}],
#  'Ealing': [{'Latitude': '51.53085',
#              'Longitude': '-0.292488',
#              'Number_of_pollutants': 2,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '2',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '2',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'EA6',
#              'Site_name': 'Hanger Lane Gyratory',
#              'Site_type': 'Roadside',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.518948',
#              'Longitude': '-0.265617',
#              'Number_of_pollutants': 2,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '2',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'EA8',
#              'Site_name': 'Horn Lane',
#              'Site_type': 'Industrial',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.5236078191481',
#              'Longitude': '-0.265502631799754',
#              'Number_of_pollutants': 2,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'EI1',
#              'Site_name': 'Western Avenue',
#              'Site_type': 'Roadside',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.5189160348806',
#              'Longitude': '-0.265652052386222',
#              'Number_of_pollutants': 1,
#              'Pollutants': [{'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'EI8',
#              'Site_name': 'Horn Lane TEOM',
#              'Site_type': 'Industrial',
#              'Updated': '2017-08-01 04:00:00'}],
#  'Enfield': [{'Latitude': '51.6450367266602',
#               'Longitude': '-0.0661800662229116',
#               'Number_of_pollutants': 1,
#               'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'NO2 is Low'}],
#               'Pollutants_status': 'Low',
#               'Site_code': 'EN1',
#               'Site_name': 'Bush Hill Park',
#               'Site_type': 'Suburban',
#               'Updated': '2017-08-01 04:00:00'},
#              {'Latitude': '51.614864007',
#               'Longitude': '-0.0507658363689',
#               'Number_of_pollutants': 2,
#               'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'NO2 is Low'},
#                              {'Code': 'SO2',
#                               'Description': 'Sulphur Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'SO2 is Low'}],
#               'Pollutants_status': 'Low',
#               'Site_code': 'EN4',
#               'Site_name': 'Derby Road',
#               'Site_type': 'Roadside',
#               'Updated': '2017-08-01 04:00:00'},
#              {'Latitude': '51.613865',
#               'Longitude': '-0.125338',
#               'Number_of_pollutants': 1,
#               'Pollutants': [{'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'PM10 is Low'}],
#               'Pollutants_status': 'Low',
#               'Site_code': 'EN5',
#               'Site_name': 'Bowes Primary School',
#               'Site_type': 'Roadside',
#               'Updated': '2017-08-01 04:00:00'},
#              {'Latitude': '51.66864334727',
#               'Longitude': '-0.02200720557',
#               'Number_of_pollutants': 1,
#               'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'NO2 is Low'}],
#               'Pollutants_status': 'Low',
#               'Site_code': 'EN7',
#               'Site_name': 'Prince of Wales School',
#               'Site_type': 'Urban Background',
#               'Updated': '2017-08-01 04:00:00'}],
#  'Greenwich': [{'Latitude': '51.490532',
#                 'Longitude': '0.074003',
#                 'Number_of_pollutants': 3,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM10 is Low'},
#                                {'Code': 'PM25',
#                                 'Description': 'PM2.5 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM25 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'GN0',
#                 'Site_name': 'A206 Burrage Grove',
#                 'Site_type': 'Roadside',
#                 'Updated': '2017-08-01 04:00:00'},
#                {'Latitude': '51.486957',
#                 'Longitude': '0.095111',
#                 'Number_of_pollutants': 4,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'O3 is Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM10 is Low'},
#                                {'Code': 'PM25',
#                                 'Description': 'PM2.5 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM25 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'GN3',
#                 'Site_name': 'Plumstead High Street',
#                 'Site_type': 'Roadside',
#                 'Updated': '2017-08-01 04:00:00'},
#                {'Latitude': '51.4346627060562',
#                 'Longitude': '0.0642224671704697',
#                 'Number_of_pollutants': 2,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM10 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'GN4',
#                 'Site_name': 'Fiveways Sidcup Rd A20',
#                 'Site_type': 'Roadside',
#                 'Updated': '2017-08-01 04:00:00'},
#                {'Latitude': '51.45258',
#                 'Longitude': '0.070766',
#                 'Number_of_pollutants': 5,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '2',
#                                 'Quality': 'Low',
#                                 'Summary': 'O3 is Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM10 is Low'},
#                                {'Code': 'PM25',
#                                 'Description': 'PM2.5 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM25 is Low'},
#                                {'Code': 'SO2',
#                                 'Description': 'Sulphur Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'SO2 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'GR4',
#                 'Site_name': 'Eltham',
#                 'Site_type': 'Suburban',
#                 'Updated': '2017-08-01 04:00:00'},
#                {'Latitude': '51.472504',
#                 'Longitude': '-0.012381',
#                 'Number_of_pollutants': 2,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM10 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'GR7',
#                 'Site_name': 'Blackheath',
#                 'Site_type': 'Roadside',
#                 'Updated': '2017-08-01 04:00:00'},
#                {'Latitude': '51.486884',
#                 'Longitude': '0.017901',
#                 'Number_of_pollutants': 2,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'O3 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'GR8',
#                 'Site_name': 'Woolwich Flyover',
#                 'Site_type': 'Roadside',
#                 'Updated': '2017-08-01 04:00:00'},
#                {'Latitude': '51.456357',
#                 'Longitude': '0.040725',
#                 'Number_of_pollutants': 4,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'O3 is Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM10 is Low'},
#                                {'Code': 'PM25',
#                                 'Description': 'PM2.5 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM25 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'GR9',
#                 'Site_name': 'Westhorne Avenue',
#                 'Site_type': 'Roadside',
#                 'Updated': '2017-08-01 04:00:00'}],
#  'Hackney': [{'Latitude': '51.526454',
#               'Longitude': '-0.08491',
#               'Number_of_pollutants': 3,
#               'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'NO2 is Low'},
#                              {'Code': 'O3',
#                               'Description': 'Ozone',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'O3 is Low'},
#                              {'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '1',
#                               'Quality': 'Low',
#                               'Summary': 'PM10 is Low'}],
#               'Pollutants_status': 'Low',
#               'Site_code': 'HK6',
#               'Site_name': 'Old Street',
#               'Site_type': 'Roadside',
#               'Updated': '2017-08-01 04:00:00'}],
#  'Hammersmith and Fulham': [{'Latitude': '51.5045625671557',
#                              'Longitude': '-0.224670007031603',
#                              'Number_of_pollutants': 2,
#                              'Pollutants': [{'Code': 'NO2',
#                                              'Description': 'Nitrogen Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low',
#                                              'Summary': 'NO2 is Low'},
#                                             {'Code': 'PM10',
#                                              'Description': 'PM10 Particulate',
#                                              'Index': '2',
#                                              'Quality': 'Low',
#                                              'Summary': 'PM10 is Low'}],
#                              'Pollutants_status': 'Low',
#                              'Site_code': 'HF4',
#                              'Site_name': 'Shepherds Bush',
#                              'Site_type': 'Roadside',
#                              'Updated': '2017-08-01 04:00:00'}],
#  'Haringey': [{'Latitude': '51.599302',
#                'Longitude': '-0.068218',
#                'Number_of_pollutants': 1,
#                'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low',
#                                'Summary': 'NO2 is Low'}],
#                'Pollutants_status': 'Low',
#                'Site_code': 'HG1',
#                'Site_name': 'Haringey Town Hall',
#                'Site_type': 'Roadside',
#                'Updated': '2017-08-01 04:00:00'},
#               {'Latitude': '51.5839769007709',
#                'Longitude': '-0.125400278484885',
#                'Number_of_pollutants': 2,
#                'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low',
#                                'Summary': 'NO2 is Low'},
#                               {'Code': 'O3',
#                                'Description': 'Ozone',
#                                'Index': '2',
#                                'Quality': 'Low',
#                                'Summary': 'O3 is Low'}],
#                'Pollutants_status': 'Low',
#                'Site_code': 'HG4',
#                'Site_name': 'Priory Park South',
#                'Site_type': 'Urban Background',
#                'Updated': '2017-08-01 04:00:00'}],
#  'Harrow': [{'Latitude': '51.617327',
#              'Longitude': '-0.298775',
#              'Number_of_pollutants': 0,
#              'Pollutants': ['No_species_data'],
#              'Pollutants_status': 'No_species_data',
#              'Site_code': 'HR1',
#              'Site_name': 'Stanmore',
#              'Site_type': 'Urban Background',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.588417',
#              'Longitude': '-0.362989',
#              'Number_of_pollutants': 1,
#              'Pollutants': [{'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'HR2',
#              'Site_name': 'Pinner Road',
#              'Site_type': 'Roadside',
#              'Updated': '2017-08-01 04:00:00'}],
#  'Havering': [{'Latitude': '51.520787459334',
#                'Longitude': '0.205460705694044',
#                'Number_of_pollutants': 1,
#                'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low',
#                                'Summary': 'NO2 is Low'}],
#                'Pollutants_status': 'Low',
#                'Site_code': 'HV1',
#                'Site_name': 'Rainham',
#                'Site_type': 'Roadside',
#                'Updated': '2017-08-01 04:00:00'},
#               {'Latitude': '51.572976',
#                'Longitude': '0.179079',
#                'Number_of_pollutants': 2,
#                'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low',
#                                'Summary': 'NO2 is Low'},
#                               {'Code': 'PM10',
#                                'Description': 'PM10 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low',
#                                'Summary': 'PM10 is Low'}],
#                'Pollutants_status': 'Low',
#                'Site_code': 'HV3',
#                'Site_name': 'Romford',
#                'Site_type': 'Roadside',
#                'Updated': '2017-08-01 04:00:00'}],
#  'Hillingdon': [{'Latitude': '51.496309',
#                  'Longitude': '-0.460826',
#                  'Number_of_pollutants': 2,
#                  'Pollutants': [{'Code': 'NO2',
#                                  'Description': 'Nitrogen Dioxide',
#                                  'Index': '1',
#                                  'Quality': 'Low',
#                                  'Summary': 'NO2 is Low'},
#                                 {'Code': 'O3',
#                                  'Description': 'Ozone',
#                                  'Index': '1',
#                                  'Quality': 'Low',
#                                  'Summary': 'O3 is Low'}],
#                  'Pollutants_status': 'Low',
#                  'Site_code': 'HI0',
#                  'Site_name': 'Keats Way',
#                  'Site_type': 'Suburban',
#                  'Updated': '2017-08-01 04:00:00'},
#                 {'Latitude': '51.48878',
#                  'Longitude': '-0.441627',
#                  'Number_of_pollutants': 0,
#                  'Pollutants': ['No_species_data'],
#                  'Pollutants_status': 'No_species_data',
#                  'Site_code': 'LH0',
#                  'Site_name': 'Harlington',
#                  'Site_type': 'Urban Background',
#                  'Updated': '2017-08-01 04:00:00'}],
#  'Islington': [{'Latitude': '51.555378',
#                 'Longitude': '-0.116146',
#                 'Number_of_pollutants': 2,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM10 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'IS2',
#                 'Site_name': 'Holloway Road',
#                 'Site_type': 'Roadside',
#                 'Updated': '2017-08-01 04:00:00'},
#                {'Latitude': '51.557895',
#                 'Longitude': '-0.106989',
#                 'Number_of_pollutants': 2,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM10 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'IS6',
#                 'Site_name': 'Arsenal',
#                 'Site_type': 'Urban Background',
#                 'Updated': '2017-08-01 04:00:00'}],
#  'Kensington and Chelsea': [{'Latitude': '51.5210467476039',
#                              'Longitude': '-0.213492139585065',
#                              'Number_of_pollutants': 4,
#                              'Pollutants': [{'Code': 'NO2',
#                                              'Description': 'Nitrogen Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low',
#                                              'Summary': 'NO2 is Low'},
#                                             {'Code': 'O3',
#                                              'Description': 'Ozone',
#                                              'Index': '2',
#                                              'Quality': 'Low',
#                                              'Summary': 'O3 is Low'},
#                                             {'Code': 'PM25',
#                                              'Description': 'PM2.5 Particulate',
#                                              'Index': '1',
#                                              'Quality': 'Low',
#                                              'Summary': 'PM25 is Low'},
#                                             {'Code': 'SO2',
#                                              'Description': 'Sulphur Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low',
#                                              'Summary': 'SO2 is Low'}],
#                              'Pollutants_status': 'Low',
#                              'Site_code': 'KC1',
#                              'Site_name': 'North Ken',
#                              'Site_type': 'Urban Background',
#                              'Updated': '2017-08-01 04:00:00'},
#                             {'Latitude': '51.49550391',
#                              'Longitude': '-0.178809464',
#                              'Number_of_pollutants': 3,
#                              'Pollutants': [{'Code': 'NO2',
#                                              'Description': 'Nitrogen Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low',
#                                              'Summary': 'NO2 is Low'},
# ...
#                'Site_type': 'Suburban',
#                'Updated': '2017-08-01 04:00:00'}],
#  'Southwark': [{'Latitude': '51.4804994936467',
#                 'Longitude': '-0.0595528932573422',
#                 'Number_of_pollutants': 0,
#                 'Pollutants': ['No_species_data'],
#                 'Pollutants_status': 'No_species_data',
#                 'Site_code': 'SK5',
#                 'Site_name': 'A2 Old Kent Road',
#                 'Site_type': 'Roadside',
#                 'Updated': '2017-08-01 04:00:00'},
#                {'Latitude': '51.4931557048667',
#                 'Longitude': '-0.101527038274853',
#                 'Number_of_pollutants': 3,
#                 'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'NO2 is Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'O3 is Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low',
#                                 'Summary': 'PM10 is Low'}],
#                 'Pollutants_status': 'Low',
#                 'Site_code': 'SK6',
#                 'Site_name': 'Elephant and Castle',
#                 'Site_type': 'Urban Background',
#                 'Updated': '2017-08-01 04:00:00'}],
#  'Sutton': [{'Latitude': '51.3586596124998',
#              'Longitude': '-0.149723946604927',
#              'Number_of_pollutants': 1,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'ST4',
#              'Site_name': 'Wallington',
#              'Site_type': 'Kerbside',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.389286904505',
#              'Longitude': '-0.141661524779893',
#              'Number_of_pollutants': 2,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '2',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'ST5',
#              'Site_name': 'Beddington Lane north',
#              'Site_type': 'Industrial',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.377923',
#              'Longitude': '-0.240414',
#              'Number_of_pollutants': 2,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'ST6',
#              'Site_name': 'Worcester Park',
#              'Site_type': 'Kerbside',
#              'Updated': '2017-08-01 04:00:00'},
#             {'Latitude': '51.3835652277943',
#              'Longitude': '-0.1364178614733',
#              'Number_of_pollutants': 2,
#              'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low',
#                              'Summary': 'NO2 is Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '2',
#                              'Quality': 'Low',
#                              'Summary': 'PM10 is Low'}],
#              'Pollutants_status': 'Low',
#              'Site_code': 'ST8',
#              'Site_name': 'Beddington Lane',
#              'Site_type': 'Industrial',
#              'Updated': '2017-08-01 04:00:00'}],
#  'Tower Hamlets': [{'Latitude': '51.5225294860844',
#                     'Longitude': '-0.0421550991900347',
#                     'Number_of_pollutants': 1,
#                     'Pollutants': [{'Code': 'NO2',
#                                     'Description': 'Nitrogen Dioxide',
#                                     'Index': '1',
#                                     'Quality': 'Low',
#                                     'Summary': 'NO2 is Low'}],
#                     'Pollutants_status': 'Low',
#                     'Site_code': 'TH2',
#                     'Site_name': 'Mile End Road',
#                     'Site_type': 'Roadside',
#                     'Updated': '2017-08-01 04:00:00'},
#                    {'Latitude': '51.5150461674013',
#                     'Longitude': '-0.00841849265642741',
#                     'Number_of_pollutants': 4,
#                     'Pollutants': [{'Code': 'NO2',
#                                     'Description': 'Nitrogen Dioxide',
#                                     'Index': '1',
#                                     'Quality': 'Low',
#                                     'Summary': 'NO2 is Low'},
#                                    {'Code': 'O3',
#                                     'Description': 'Ozone',
#                                     'Index': '1',
#                                     'Quality': 'Low',
#                                     'Summary': 'O3 is Low'},
#                                    {'Code': 'PM10',
#                                     'Description': 'PM10 Particulate',
#                                     'Index': '1',
#                                     'Quality': 'Low',
#                                     'Summary': 'PM10 is Low'},
#                                    {'Code': 'PM25',
#                                     'Description': 'PM2.5 Particulate',
#                                     'Index': '1',
#                                     'Quality': 'Low',
#                                     'Summary': 'PM25 is Low'}],
#                     'Pollutants_status': 'Low',
#                     'Site_code': 'TH4',
#                     'Site_name': 'Blackwall',
#                     'Site_type': 'Roadside',
#                     'Updated': '2017-08-01 04:00:00'}],
#  'Wandsworth': [{'Latitude': '51.456962',
#                  'Longitude': '-0.191074',
#                  'Number_of_pollutants': 1,
#                  'Pollutants': [{'Code': 'NO2',
#                                  'Description': 'Nitrogen Dioxide',
#                                  'Index': '1',
#                                  'Quality': 'Low',
#                                  'Summary': 'NO2 is Low'}],
#                  'Pollutants_status': 'Low',
#                  'Site_code': 'WA2',
#                  'Site_name': 'Wandsworth Town Hall',
#                  'Site_type': 'Urban Background',
#                  'Updated': '2017-08-01 04:00:00'},
#                 {'Latitude': '51.463429',
#                  'Longitude': '-0.215871',
#                  'Number_of_pollutants': 1,
#                  'Pollutants': [{'Code': 'PM10',
#                                  'Description': 'PM10 Particulate',
#                                  'Index': '1',
#                                  'Quality': 'Low',
#                                  'Summary': 'PM10 is Low'}],
#                  'Pollutants_status': 'Low',
#                  'Site_code': 'WA7',
#                  'Site_name': 'Putney High Street',
#                  'Site_type': 'Kerbside',
#                  'Updated': '2017-08-01 04:00:00'},
#                 {'Latitude': '51.4637206047191',
#                  'Longitude': '-0.215890144123119',
#                  'Number_of_pollutants': 0,
#                  'Pollutants': ['No_species_data'],
#                  'Pollutants_status': 'No_species_data',
#                  'Site_code': 'WA8',
#                  'Site_name': 'Putney High Street Facade',
#                  'Site_type': 'Roadside',
#                  'Updated': '2017-08-01 04:00:00'},
#                 {'Latitude': '51.4650325059122',
#                  'Longitude': '-0.215824580947572',
#                  'Number_of_pollutants': 0,
#                  'Pollutants': ['No_species_data'],
#                  'Pollutants_status': 'No_species_data',
#                  'Site_code': 'WA9',
#                  'Site_name': 'Putney',
#                  'Site_type': 'Urban Background',
#                  'Updated': '2017-08-01 04:00:00'},
#                 {'Latitude': '51.4794395281222',
#                  'Longitude': '-0.141786953606306',
#                  'Number_of_pollutants': 0,
#                  'Pollutants': ['No_species_data'],
#                  'Pollutants_status': 'No_species_data',
#                  'Site_code': 'WAA',
#                  'Site_name': 'Battersea',
#                  'Site_type': 'Roadside',
#                  'Updated': '2017-08-01 04:00:00'},
#                 {'Latitude': '51.429331',
#                  'Longitude': '-0.166524',
#                  'Number_of_pollutants': 1,
#                  'Pollutants': [{'Code': 'PM10',
#                                  'Description': 'PM10 Particulate',
#                                  'Index': '1',
#                                  'Quality': 'Low',
#                                  'Summary': 'PM10 is Low'}],
#                  'Pollutants_status': 'Low',
#                  'Site_code': 'WAB',
#                  'Site_name': 'Tooting High Street',
#                  'Site_type': 'Roadside',
#                  'Updated': '2017-08-01 04:00:00'},
#                 {'Latitude': '51.4636903568111',
#                  'Longitude': '-0.166713485994806',
#                  'Number_of_pollutants': 2,
#                  'Pollutants': [{'Code': 'NO2',
#                                  'Description': 'Nitrogen Dioxide',
#                                  'Index': '1',
#                                  'Quality': 'Low',
#                                  'Summary': 'NO2 is Low'},
#                                 {'Code': 'PM10',
#                                  'Description': 'PM10 Particulate',
#                                  'Index': '1',
#                                  'Quality': 'Low',
#                                  'Summary': 'PM10 is Low'}],
#                  'Pollutants_status': 'Low',
#                  'Site_code': 'WAC',
#                  'Site_name': 'Lavender Hill (Clapham Jct)',
#                  'Site_type': 'Roadside',
#                  'Updated': '2017-08-01 04:00:00'}],
#  'Westminster': [{'Latitude': '51.52254',
#                   'Longitude': '-0.15459',
#                   'Number_of_pollutants': 4,
#                   'Pollutants': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low',
#                                   'Summary': 'NO2 is Low'},
#                                  {'Code': 'O3',
#                                   'Description': 'Ozone',
#                                   'Index': '1',
#                                   'Quality': 'Low',
#                                   'Summary': 'O3 is Low'},
#                                  {'Code': 'PM10',
#                                   'Description': 'PM10 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low',
#                                   'Summary': 'PM10 is Low'},
#                                  {'Code': 'SO2',
#                                   'Description': 'Sulphur Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low',
#                                   'Summary': 'SO2 is Low'}],
#                   'Pollutants_status': 'Low',
#                   'Site_code': 'MY1',
#                   'Site_name': 'Marylebone Road',
#                   'Site_type': 'Kerbside',
#                   'Updated': '2017-08-01 04:00:00'},
#                  {'Latitude': '51.52254',
#                   'Longitude': '-0.15459',
#                   'Number_of_pollutants': 1,
#                   'Pollutants': [{'Code': 'PM10',
#                                   'Description': 'PM10 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low',
#                                   'Summary': 'PM10 is Low'}],
#                   'Pollutants_status': 'Low',
#                   'Site_code': 'MY7',
#                   'Site_name': 'Marylebone Road FDMS',
#                   'Site_type': 'Kerbside',
#                   'Updated': '2017-08-01 04:00:00'},
#                  {'Latitude': '51.511998',
#                   'Longitude': '-0.116715',
#                   'Number_of_pollutants': 0,
#                   'Pollutants': ['No_species_data'],
#                   'Pollutants_status': 'No_species_data',
#                   'Site_code': 'NB1',
#                   'Site_name': 'Strand (Northbank BID)',
#                   'Site_type': 'Roadside',
#                   'Updated': '2017-08-01 04:00:00'},
#                  {'Latitude': '51.494681',
#                   'Longitude': '-0.131938',
#                   'Number_of_pollutants': 2,
#                   'Pollutants': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low',
#                                   'Summary': 'NO2 is Low'},
#                                  {'Code': 'PM10',
#                                   'Description': 'PM10 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low',
#                                   'Summary': 'PM10 is Low'}],
#                   'Pollutants_status': 'Low',
#                   'Site_code': 'WM0',
#                   'Site_name': 'Horseferry Road',
#                   'Site_type': 'Urban Background',
#                   'Updated': '2017-08-01 04:00:00'},
#                  {'Latitude': '51.5139287404213',
#                   'Longitude': '-0.152792701881935',
#                   'Number_of_pollutants': 1,
#                   'Pollutants': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low',
#                                   'Summary': 'NO2 is Low'}],
#                   'Pollutants_status': 'Low',
#                   'Site_code': 'WM6',
#                   'Site_name': 'Oxford Street',
#                   'Site_type': 'Kerbside',
#                   'Updated': '2017-08-01 04:00:00'},
#                  {'Latitude': '51.4977331829735',
#                   'Longitude': '-0.14424140916201',
#                   'Number_of_pollutants': 1,
#                   'Pollutants': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low',
#                                   'Summary': 'NO2 is Low'}],
#                   'Pollutants_status': 'Low',
#                   'Site_code': 'WM9',
#                   'Site_name': 'Victoria (Victoria BID)',
#                   'Site_type': 'Roadside',
#                   'Updated': '2017-08-01 04:00:00'}]}

# %%
class AirData(object):
    """Get the latest data."""

    def __init__(self):
        """Initialize the AirData object."""
        self.data = None

    def update(self):
        """Get the latest data from TFL."""
        response = requests.get(URL)
        if response.status_code != 200:
            _LOGGER.warning("Invalid response from API")
        else:
            self.data = parse_api_response(response.json())

# %%
# Class will return dict of attributes of form

attributes = {'LocalAuthorityName': 'Kingston', 
              'SiteCode': 'KT4',
              'SiteName': 'Kingston upon thames',
              '@BulletinDate': '2017-07-04 03:00:00',              # Will be sensor state
              'species': [
        {'@AirQualityBand': 'Low',
         '@AirQualityIndex': '1',
         '@IndexSource': 'Trigger',
         '@SpeciesCode': 'PM10',
         '@SpeciesName': 'PM10 Particulate'}
    ]}
