# %% [markdown]
# https://www.londonair.org.uk/LondonAir/API/
#
# Docs http://api.erg.kcl.ac.uk/AirQuality/Information/Documentation/pdf

# %%
import requests
import json
import pprint

def print_json(json_data):
    pprint.PrettyPrinter().pprint(json_data)

# %% [markdown]
# # Single site - Hourly

# %%
SiteCode = 'KT4'
url = 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/SiteCode={}/Json'.format(SiteCode)
url
# Out:
# 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/SiteCode=KT4/Json'

# %%
response = requests.get(url).json()  # get the response object

# %%
print_json(response)
# Out:
# {'HourlyAirQualityIndex': {'@TimeToLive': '33',
#                            'LocalAuthority': {'@LaCentreLatitude': '51.412317',
#                                               '@LaCentreLatitudeWGS84': '6694554.466476',
#                                               '@LaCentreLongitude': '-0.300443',
#                                               '@LaCentreLongitudeWGS84': '-33445.161772',
#                                               '@LocalAuthorityCode': '21',
#                                               '@LocalAuthorityName': 'Kingston',
#                                               'Site': {'@BulletinDate': '2017-07-30 '
#                                                                         '19:00:00',
#                                                        '@Latitude': '51.379312',
#                                                        '@LatitudeWGS84': '6688665.88821522',
#                                                        '@Longitude': '-0.281259',
#                                                        '@LongitudeWGS84': '-31309.6086610253',
#                                                        '@SiteCode': 'KT4',
#                                                        '@SiteName': 'Kingston '
#                                                                     'Upon '
#                                                                     'Thames - '
#                                                                     'Tolworth '
#                                                                     'Broadway',
#                                                        '@SiteType': 'Roadside',
#                                                        'species': [{'@AirQualityBand': 'Low',
#                                                                     '@AirQualityIndex': '1',
#                                                                     '@IndexSource': 'Measurement',
#                                                                     '@SpeciesCode': 'NO2',
#                                                                     '@SpeciesName': 'Nitrogen '
#                                                                                     'Dioxide'},
#                                                                    {'@AirQualityBand': 'Low',
#                                                                     '@AirQualityIndex': '1',
#                                                                     '@IndexSource': 'Trigger',
#                                                                     '@SpeciesCode': 'PM10',
#                                                                     '@SpeciesName': 'PM10 '
#                                                                                     'Particulate'}]}}}}

# %%
base = response['HourlyAirQualityIndex']['LocalAuthority']['Site']

# %%
base['@SiteName']
# Out:
# 'Kingston Upon Thames - Tolworth Broadway'

# %%
for species in base['species']:
    print('*****')
    print(species['@SpeciesName'])
    print(species['@AirQualityIndex'])
    print(species['@AirQualityBand'])
# Out:
# *****
# Nitrogen Dioxide
# 1
# Low
# *****
# PM10 Particulate
# 1
# Low

# %% [markdown]
# # All sites - Hourly

# %%
url = 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/GroupName=London/Json'
response = requests.get(url).json()  # get the response object

# %%
base = response['HourlyAirQualityIndex']['LocalAuthority']
print(len(base))   # 33 sites
autorities_with_site = []
authorities = []

for authority in base:
    authorities.append(authority['@LocalAuthorityName'])
    if 'Site' in authority.keys():
        #print(authority['@LocalAuthorityName'])
        autorities_with_site.append(authority['@LocalAuthorityName'])
        
print(len(autorities_with_site))
print(list(set(set(authorities) - set(autorities_with_site))))
# Out:
# 33
# 28
# ['Bromley', 'Newham', 'Hounslow', 'Waltham Forest', 'Barnet']

# %%
data = {}

for authority in base:
    if authority['@LocalAuthorityName'] == 'Kingston':
        data = authority
        
data
# Out:
# {'@LaCentreLatitude': '51.412317',
#  '@LaCentreLatitudeWGS84': '6694554.466476',
#  '@LaCentreLongitude': '-0.300443',
#  '@LaCentreLongitudeWGS84': '-33445.161772',
#  '@LocalAuthorityCode': '21',
#  '@LocalAuthorityName': 'Kingston',
#  'Site': {'@BulletinDate': '2017-07-30 19:00:00',
#   '@Latitude': '51.379312',
#   '@LatitudeWGS84': '6688665.88821522',
#   '@Longitude': '-0.281259',
#   '@LongitudeWGS84': '-31309.6086610253',
#   '@SiteCode': 'KT4',
#   '@SiteName': 'Kingston Upon Thames - Tolworth Broadway',
#   '@SiteType': 'Roadside',
#   'Species': [{'@AirQualityBand': 'Low',
#     '@AirQualityIndex': '1',
#     '@IndexSource': 'Measurement',
#     '@SpeciesCode': 'NO2',
#     '@SpeciesDescription': 'Nitrogen Dioxide'},
#    {'@AirQualityBand': 'Low',
#     '@AirQualityIndex': '1',
#     '@IndexSource': 'Trigger',
#     '@SpeciesCode': 'PM10',
#     '@SpeciesDescription': 'PM10 Particulate'}]}}

# %%
# If only 1 site, then a dict is returned so wrap in a list to ensure a list ia parsed in next step
if isinstance(data['Site'], dict):
    site_data = [data['Site']]  
else:
    site_data = data['Site']  
    for site in site_data:
        print(site['@SiteName'])
        if site['Species']['@AirQualityBand'] != 'No data':      # don't print if no data
            print(site['Species']['@AirQualityBand'])
            print(site['Species']['@AirQualityIndex'])
            print(site['Species']['@SpeciesDescription'])

# %%
print(len(base[2]['Site']))   # there are 8 sites
for site in base[2]['Site']:
    print(site['@SiteName'])
# Out:
# 8
# Bexley - Belvedere West
# Bexley - Belvedere West FDMS
# Bexley - Belvedere FDMS
# Bexley - Slade Green
# Bexley - Belvedere
# Bexley - Slade Green FDMS
# Greenwich and Bexley - Falconwood FDMS
# Greenwich and Bexley - Falconwood

# %% [markdown]
# # HASS class

# %%
LOCATIONS = 'Locations'
URL = 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/GroupName=London/Json'
#SCAN_INTERVAL = timedelta(seconds=30)

# Remove authorities without any Sites ['Hounslow', 'Bromley', 'Waltham Forest', 'Barnet', 'Newham']
AUTHORITIES = [
    'Barking and Dagenham',
    'Bexley',
    'Brent',
    'Camden',
    'City of London',
    'Croydon',
    'Ealing',
    'Enfield',
    'Greenwich',
    'Hackney',
    'Hammersmith and Fulham',
    'Haringey',
    'Harrow',
    'Havering',
    'Hillingdon',
    'Islington',
    'Kensington and Chelsea',
    'Kingston',
    'Lambeth',
    'Lewisham',
    'Merton',
    'Redbridge',
    'Richmond',
    'Southwark',
    'Sutton',
    'Tower Hamlets',
    'Wandsworth',
    'Westminster']

CONFIG = {LOCATIONS: ['Merton','Richmond',]}  # A list of required locations

# %%
def parse_api_response(response):
    """Take in the API response. API can return dict or list of data so need to check. """
    data = dict.fromkeys(AUTHORITIES)     # Holds all data
    for authority in AUTHORITIES:
        for entry in response['HourlyAirQualityIndex']['LocalAuthority']:   # Loop over entries
            if entry['@LocalAuthorityName'] == authority:
                authority_data = []
                
                if isinstance(entry['Site'], dict):
                    entry_sites_data = [entry['Site']]  
                else:
                    entry_sites_data = entry['Site']  
                
                for site in entry_sites_data:
                    site_data = {}
                    species_data = []
                    
                    site_data['Site code'] = site['@SiteCode']
                    site_data['Site name'] = site['@SiteName']  
                    
                    if isinstance(site['Species'], dict):
                        species_data = [site['Species']]  
                    else:
                        species_data = site['Species'] 
                    
                    parsed_species_data = []
                    for species in species_data:
                        if species['@AirQualityBand'] != 'No data': 
                            species_dict = {}
                            species_dict['Description'] = species['@SpeciesDescription']
                            species_dict['Code'] = species['@SpeciesCode']
                            species_dict['Quality'] = species['@AirQualityBand']
                            species_dict['Index'] = species['@AirQualityIndex']
                            parsed_species_data.append(species_dict)
                    
                    if not parsed_species_data:      # if no valid species data
                        parsed_species_data.append('No species data')

                    site_data['Species'] = parsed_species_data
                    authority_data.append(site_data)
                    
                data[authority] = authority_data

    return data

# %%
response = requests.get(URL).json()
my_data = parse_api_response(response)

# %%
my_data.keys()
# Out:
# dict_keys(['Hackney', 'Camden', 'Greenwich', 'Tower Hamlets', 'Lambeth', 'Havering', 'Kingston', 'Southwark', 'Kensington and Chelsea', 'Hillingdon', 'Sutton', 'Redbridge', 'Lewisham', 'Croydon', 'Richmond', 'Bexley', 'Haringey', 'Hammersmith and Fulham', 'Wandsworth', 'Brent', 'City of London', 'Barking and Dagenham', 'Enfield', 'Westminster', 'Harrow', 'Islington', 'Ealing', 'Merton'])

# %%
my_data['Merton']
# Out:
# [{'Site code': 'ME2',
#   'Site name': 'Merton - Merton Road',
#   'Species': [{'Code': 'PM10',
#     'Description': 'PM10 Particulate',
#     'Index': '2',
#     'Quality': 'Low'}]},
#  {'Site code': 'ME9',
#   'Site name': 'Merton - Morden Civic Centre 2',
#   'Species': [{'Code': 'NO2',
#     'Description': 'Nitrogen Dioxide',
#     'Index': '1',
#     'Quality': 'Low'}]}]

# %%
print_json(my_data)
# Out:
# {'Barking and Dagenham': [{'Site code': 'BG1',
#                            'Site name': 'Barking and Dagenham - Rush Green',
#                            'Species': [{'Code': 'NO2',
#                                         'Description': 'Nitrogen Dioxide',
#                                         'Index': '1',
#                                         'Quality': 'Low'},
#                                        {'Code': 'SO2',
#                                         'Description': 'Sulphur Dioxide',
#                                         'Index': '1',
#                                         'Quality': 'Low'}]},
#                           {'Site code': 'BG2',
#                            'Site name': 'Barking and Dagenham - Scrattons Farm',
#                            'Species': [{'Code': 'NO2',
#                                         'Description': 'Nitrogen Dioxide',
#                                         'Index': '1',
#                                         'Quality': 'Low'},
#                                        {'Code': 'PM10',
#                                         'Description': 'PM10 Particulate',
#                                         'Index': '1',
#                                         'Quality': 'Low'}]}],
#  'Bexley': [{'Site code': 'BQ7',
#              'Site name': 'Bexley - Belvedere West',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'O3',
#                           'Description': 'Ozone',
#                           'Index': '2',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'BQ8',
#              'Site name': 'Bexley - Belvedere West FDMS',
#              'Species': ['No species data']},
#             {'Site code': 'BX0',
#              'Site name': 'Bexley - Belvedere FDMS',
#              'Species': [{'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'BX1',
#              'Site name': 'Bexley - Slade Green',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'O3',
#                           'Description': 'Ozone',
#                           'Index': '3',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'SO2',
#                           'Description': 'Sulphur Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'BX2',
#              'Site name': 'Bexley - Belvedere',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'BX9',
#              'Site name': 'Bexley - Slade Green FDMS',
#              'Species': [{'Code': 'PM25',
#                           'Description': 'PM2.5 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'GB0',
#              'Site name': 'Greenwich and Bexley - Falconwood FDMS',
#              'Species': [{'Code': 'PM25',
#                           'Description': 'PM2.5 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'GB6',
#              'Site name': 'Greenwich and Bexley - Falconwood',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'O3',
#                           'Description': 'Ozone',
#                           'Index': '2',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]}],
#  'Brent': [{'Site code': 'BT4',
#             'Site name': 'Brent - Ikea',
#             'Species': [{'Code': 'NO2',
#                          'Description': 'Nitrogen Dioxide',
#                          'Index': '1',
#                          'Quality': 'Low'},
#                         {'Code': 'O3',
#                          'Description': 'Ozone',
#                          'Index': '2',
#                          'Quality': 'Low'},
#                         {'Code': 'PM10',
#                          'Description': 'PM10 Particulate',
#                          'Index': '1',
#                          'Quality': 'Low'}]},
#            {'Site code': 'BT5',
#             'Site name': 'Brent - Neasden Lane',
#             'Species': [{'Code': 'NO2',
#                          'Description': 'Nitrogen Dioxide',
#                          'Index': '1',
#                          'Quality': 'Low'},
#                         {'Code': 'PM10',
#                          'Description': 'PM10 Particulate',
#                          'Index': '2',
#                          'Quality': 'Low'}]},
#            {'Site code': 'BT6',
#             'Site name': 'Brent - John Keble Primary School',
#             'Species': [{'Code': 'NO2',
#                          'Description': 'Nitrogen Dioxide',
#                          'Index': '1',
#                          'Quality': 'Low'},
#                         {'Code': 'PM10',
#                          'Description': 'PM10 Particulate',
#                          'Index': '1',
#                          'Quality': 'Low'}]},
#            {'Site code': 'BT8',
#             'Site name': 'Brent - Ark Franklin Academy',
#             'Species': ['No species data']}],
#  'Camden': [{'Site code': 'BL0',
#              'Site name': 'Camden - Bloomsbury',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'O3',
#                           'Description': 'Ozone',
#                           'Index': '2',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM25',
#                           'Description': 'PM2.5 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'CD1',
#              'Site name': 'Camden - Swiss Cottage',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM25',
#                           'Description': 'PM2.5 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'CD9',
#              'Site name': 'Camden - Euston Road',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '2',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM25',
#                           'Description': 'PM2.5 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'IM1',
#              'Site name': 'Camden - Holborn (inmidtown)',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'}]}],
#  'City of London': [{'Site code': 'CT2',
#                      'Site name': 'City of London - Farringdon Street',
#                      'Species': [{'Code': 'PM25',
#                                   'Description': 'PM2.5 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low'}]},
#                     {'Site code': 'CT3',
#                      'Site name': 'City of London - Sir John Cass School',
#                      'Species': [{'Code': 'PM10',
#                                   'Description': 'PM10 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low'},
#                                  {'Code': 'PM25',
#                                   'Description': 'PM2.5 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low'}]},
#                     {'Site code': 'CT4',
#                      'Site name': 'City of London - Beech Street',
#                      'Species': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low'},
#                                  {'Code': 'PM10',
#                                   'Description': 'PM10 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low'}]},
#                     {'Site code': 'CT6',
#                      'Site name': 'City of London - Walbrook Wharf',
#                      'Species': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low'}]},
#                     {'Site code': 'CT8',
#                      'Site name': 'City of London - Upper Thames Street',
#                      'Species': [{'Code': 'PM10',
#                                   'Description': 'PM10 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low'}]}],
#  'Croydon': [{'Site code': 'CR5',
#               'Site name': 'Croydon - Norbury',
#               'Species': [{'Code': 'NO2',
#                            'Description': 'Nitrogen Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'}]},
#              {'Site code': 'CR7',
#               'Site name': 'Croydon - Purley Way A23',
#               'Species': [{'Code': 'NO2',
#                            'Description': 'Nitrogen Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'}]},
#              {'Site code': 'CR8',
#               'Site name': 'Croydon - Norbury Manor',
#               'Species': [{'Code': 'PM25',
#                            'Description': 'PM2.5 Particulate',
#                            'Index': '1',
#                            'Quality': 'Low'}]},
#              {'Site code': 'CR9',
#               'Site name': 'Croydon - Park Lane',
#               'Species': [{'Code': 'NO2',
#                            'Description': 'Nitrogen Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'},
#                           {'Code': 'PM10',
#                            'Description': 'PM10 Particulate',
#                            'Index': '1',
#                            'Quality': 'Low'}]}],
#  'Ealing': [{'Site code': 'EA6',
#              'Site name': 'Ealing - Hanger Lane Gyratory',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'EA8',
#              'Site name': 'Ealing - Horn Lane',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'EI1',
#              'Site name': 'Ealing - Western Avenue',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'EI8',
#              'Site name': 'Ealing - Horn Lane TEOM',
#              'Species': [{'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]}],
#  'Enfield': [{'Site code': 'EN1',
#               'Site name': 'Enfield - Bush Hill Park',
#               'Species': [{'Code': 'NO2',
#                            'Description': 'Nitrogen Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'}]},
#              {'Site code': 'EN4',
#               'Site name': 'Enfield - Derby Road',
#               'Species': [{'Code': 'NO2',
#                            'Description': 'Nitrogen Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'},
#                           {'Code': 'SO2',
#                            'Description': 'Sulphur Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'}]},
#              {'Site code': 'EN5',
#               'Site name': 'Enfield - Bowes Primary School',
#               'Species': [{'Code': 'PM10',
#                            'Description': 'PM10 Particulate',
#                            'Index': '1',
#                            'Quality': 'Low'}]},
#              {'Site code': 'EN7',
#               'Site name': 'Enfield - Prince of Wales School',
#               'Species': [{'Code': 'NO2',
#                            'Description': 'Nitrogen Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'}]}],
#  'Greenwich': [{'Site code': 'GN0',
#                 'Site name': 'Greenwich - A206 Burrage Grove',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]},
#                {'Site code': 'GN3',
#                 'Site name': 'Greenwich - Plumstead High Street',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]},
#                {'Site code': 'GN4',
#                 'Site name': 'Greenwich - Fiveways Sidcup Rd A20',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]},
#                {'Site code': 'GR4',
#                 'Site name': 'Greenwich - Eltham',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low'},
#                             {'Code': 'SO2',
#                              'Description': 'Sulphur Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'}]},
#                {'Site code': 'GR7',
#                 'Site name': 'Greenwich - Blackheath',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]},
#                {'Site code': 'GR8',
#                 'Site name': 'Greenwich - Woolwich Flyover',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '1',
#                              'Quality': 'Low'}]},
#                {'Site code': 'GR9',
#                 'Site name': 'Greenwich - Westhorne Avenue',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]}],
#  'Hackney': [{'Site code': 'HK6',
#               'Site name': 'Hackney - Old Street',
#               'Species': [{'Code': 'NO2',
#                            'Description': 'Nitrogen Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'},
#                           {'Code': 'O3',
#                            'Description': 'Ozone',
#                            'Index': '2',
#                            'Quality': 'Low'},
#                           {'Code': 'PM10',
#                            'Description': 'PM10 Particulate',
#                            'Index': '1',
#                            'Quality': 'Low'}]}],
#  'Hammersmith and Fulham': [{'Site code': 'HF4',
#                              'Site name': 'Hammersmith and Fulham - Shepherds '
#                                           'Bush',
#                              'Species': [{'Code': 'NO2',
#                                           'Description': 'Nitrogen Dioxide',
#                                           'Index': '1',
#                                           'Quality': 'Low'},
#                                          {'Code': 'PM10',
#                                           'Description': 'PM10 Particulate',
#                                           'Index': '1',
#                                           'Quality': 'Low'}]}],
#  'Haringey': [{'Site code': 'HG1',
#                'Site name': 'Haringey - Haringey Town Hall',
#                'Species': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'}]},
#               {'Site code': 'HG4',
#                'Site name': 'Haringey  - Priory Park South',
#                'Species': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'O3',
#                             'Description': 'Ozone',
#                             'Index': '2',
#                             'Quality': 'Low'}]}],
#  'Harrow': [{'Site code': 'HR1',
#              'Site name': 'Harrow - Stanmore',
#              'Species': ['No species data']},
#             {'Site code': 'HR2',
#              'Site name': 'Harrow - Pinner Road',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]}],
#  'Havering': [{'Site code': 'HV1',
#                'Site name': 'Havering - Rainham',
#                'Species': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'}]},
#               {'Site code': 'HV3',
#                'Site name': 'Havering - Romford',
#                'Species': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'}]}],
#  'Hillingdon': [{'Site code': 'HI0',
#                  'Site name': 'Hillingdon - Keats Way',
#                  'Species': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'},
#                              {'Code': 'O3',
#                               'Description': 'Ozone',
#                               'Index': '2',
#                               'Quality': 'Low'}]},
#                 {'Site code': 'LH0',
#                  'Site name': 'Hillingdon - Harlington',
#                  'Species': ['No species data']}],
#  'Islington': [{'Site code': 'IS2',
#                 'Site name': 'Islington - Holloway Road',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]},
#                {'Site code': 'IS6',
#                 'Site name': 'Islington - Arsenal',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]}],
#  'Kensington and Chelsea': [{'Site code': 'KC1',
#                              'Site name': 'Kensington and Chelsea - North Ken',
#                              'Species': [{'Code': 'NO2',
#                                           'Description': 'Nitrogen Dioxide',
#                                           'Index': '1',
#                                           'Quality': 'Low'},
#                                          {'Code': 'O3',
#                                           'Description': 'Ozone',
#                                           'Index': '3',
#                                           'Quality': 'Low'},
#                                          {'Code': 'SO2',
#                                           'Description': 'Sulphur Dioxide',
#                                           'Index': '1',
#                                           'Quality': 'Low'}]},
#                             {'Site code': 'KC2',
#                              'Site name': 'Kensington and Chelsea - Cromwell '
#                                           'Road',
#                              'Species': [{'Code': 'NO2',
#                                           'Description': 'Nitrogen Dioxide',
#                                           'Index': '1',
#                                           'Quality': 'Low'},
#                                          {'Code': 'PM10',
#                                           'Description': 'PM10 Particulate',
#                                           'Index': '1',
#                                           'Quality': 'Low'},
#                                          {'Code': 'PM25',
#                                           'Description': 'PM2.5 Particulate',
#                                           'Index': '1',
#                                           'Quality': 'Low'}]},
#                             {'Site code': 'KC3',
#                              'Site name': 'Kensington and Chelsea - '
#                                           'Knightsbridge',
#                              'Species': [{'Code': 'NO2',
#                                           'Description': 'Nitrogen Dioxide',
#                                           'Index': '1',
#                                           'Quality': 'Low'}]},
#                             {'Site code': 'KC4',
#                              'Site name': 'Kensington and Chelsea - Kings Road',
#                              'Species': [{'Code': 'NO2',
#                                           'Description': 'Nitrogen Dioxide',
#                                           'Index': '1',
#                                           'Quality': 'Low'}]},
#                             {'Site code': 'KC5',
#                              'Site name': 'Kensington and Chelsea - Earls '
#                                           'Court Rd',
#                              'Species': [{'Code': 'NO2',
#                                           'Description': 'Nitrogen Dioxide',
#                                           'Index': '1',
#                                           'Quality': 'Low'}]},
#                             {'Site code': 'KC7',
#                              'Site name': 'Kensington and Chelsea - North Ken '
#                                           'FDMS',
#                              'Species': ['No species data']}],
#  'Kingston': [{'Site code': 'KT4',
#                'Site name': 'Kingston Upon Thames - Tolworth Broadway',
#                'Species': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'}]}],
#  'Lambeth': [{'Site code': 'LB4',
#               'Site name': 'Lambeth - Brixton Road',
#               'Species': [{'Code': 'NO2',
#                            'Description': 'Nitrogen Dioxide',
#                            'Index': '2',
#                            'Quality': 'Low'},
#                           {'Code': 'PM10',
#                            'Description': 'PM10 Particulate',
#                            'Index': '2',
#                            'Quality': 'Low'}]},
#              {'Site code': 'LB5',
#               'Site name': 'Lambeth - Bondway Interchange',
#               'Species': [{'Code': 'NO2',
#                            'Description': 'Nitrogen Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'},
#                           {'Code': 'PM10',
#                            'Description': 'PM10 Particulate',
#                            'Index': '3',
#                            'Quality': 'Low'},
#                           {'Code': 'SO2',
#                            'Description': 'Sulphur Dioxide',
#                            'Index': '1',
#                            'Quality': 'Low'}]},
#              {'Site code': 'LB6',
#               'Site name': 'Lambeth - Streatham Green',
#               'Species': ['No species data']}],
#  'Lewisham': [{'Site code': 'LW1',
#                'Site name': 'Lewisham - Catford',
#                'Species': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'}]},
#               {'Site code': 'LW2',
#                'Site name': 'Lewisham - New Cross',
#                'Species': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'PM25',
#                             'Description': 'PM2.5 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'}]},
#               {'Site code': 'LW4',
#                'Site name': 'Lewisham - Loampit Vale',
#                'Species': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'}]}],
#  'Merton': [{'Site code': 'ME2',
#              'Site name': 'Merton - Merton Road',
#              'Species': [{'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '2',
#                           'Quality': 'Low'}]},
#             {'Site code': 'ME9',
#              'Site name': 'Merton - Morden Civic Centre 2',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'}]}],
#  'Redbridge': [{'Site code': 'RB4',
#                 'Site name': 'Redbridge - Gardner Close',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]},
#                {'Site code': 'RB7',
#                 'Site name': 'Redbridge - Ley Street',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]}],
#  'Richmond': [{'Site code': 'RHG',
#                'Site name': 'Richmond Upon Thames - Chertsey Road',
#                'Species': ['No species data']},
#               {'Site code': 'RI1',
#                'Site name': 'Richmond Upon Thames - Castelnau',
#                'Species': [{'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'}]},
#               {'Site code': 'RI2',
#                'Site name': 'Richmond Upon Thames - Barnes Wetlands',
#                'Species': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'O3',
#                             'Description': 'Ozone',
#                             'Index': '2',
#                             'Quality': 'Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'}]},
#               {'Site code': 'TD0',
#                'Site name': 'Richmond Upon Thames - Ntl Physical  Lab',
#                'Species': ['No species data']},
#               {'Site code': 'TD5',
#                'Site name': 'Richmond Upon Thames - Bushy Park',
#                'Species': [{'Code': 'PM25',
#                             'Description': 'PM2.5 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'}]}],
#  'Southwark': [{'Site code': 'SK5',
#                 'Site name': 'Southwark - A2 Old Kent Road',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]},
#                {'Site code': 'SK6',
#                 'Site name': 'Southwark - Elephant and Castle',
#                 'Species': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}]}],
#  'Sutton': [{'Site code': 'ST4',
#              'Site name': 'Sutton - Wallington',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'ST5',
#              'Site name': 'Sutton - Beddington Lane north',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM25',
#                           'Description': 'PM2.5 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'ST6',
#              'Site name': 'Sutton - Worcester Park',
#              'Species': [{'Code': 'NO2',
#                           'Description': 'Nitrogen Dioxide',
#                           'Index': '1',
#                           'Quality': 'Low'},
#                          {'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]},
#             {'Site code': 'ST8',
#              'Site name': 'Sutton - Beddington Lane',
#              'Species': [{'Code': 'PM10',
#                           'Description': 'PM10 Particulate',
#                           'Index': '1',
#                           'Quality': 'Low'}]}],
#  'Tower Hamlets': [{'Site code': 'TH2',
#                     'Site name': 'Tower Hamlets - Mile End Road',
#                     'Species': [{'Code': 'NO2',
#                                  'Description': 'Nitrogen Dioxide',
#                                  'Index': '1',
#                                  'Quality': 'Low'}]},
#                    {'Site code': 'TH4',
#                     'Site name': 'Tower Hamlets - Blackwall',
#                     'Species': [{'Code': 'NO2',
#                                  'Description': 'Nitrogen Dioxide',
#                                  'Index': '1',
#                                  'Quality': 'Low'},
#                                 {'Code': 'O3',
#                                  'Description': 'Ozone',
#                                  'Index': '2',
#                                  'Quality': 'Low'},
#                                 {'Code': 'PM10',
#                                  'Description': 'PM10 Particulate',
#                                  'Index': '1',
#                                  'Quality': 'Low'},
#                                 {'Code': 'PM25',
#                                  'Description': 'PM2.5 Particulate',
#                                  'Index': '1',
#                                  'Quality': 'Low'}]}],
#  'Wandsworth': [{'Site code': 'WA2',
#                  'Site name': 'Wandsworth - Wandsworth Town Hall',
#                  'Species': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'}]},
#                 {'Site code': 'WA7',
#                  'Site name': 'Wandsworth - Putney High Street',
#                  'Species': [{'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '1',
#                               'Quality': 'Low'}]},
#                 {'Site code': 'WA8',
#                  'Site name': 'Wandsworth - Putney High Street Facade',
#                  'Species': ['No species data']},
#                 {'Site code': 'WA9',
#                  'Site name': 'Wandsworth - Putney',
#                  'Species': ['No species data']},
#                 {'Site code': 'WAA',
#                  'Site name': 'Wandsworth - Battersea',
#                  'Species': ['No species data']},
#                 {'Site code': 'WAB',
#                  'Site name': 'Wandsworth - Tooting High Street',
#                  'Species': [{'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '1',
#                               'Quality': 'Low'}]},
#                 {'Site code': 'WAC',
#                  'Site name': 'Wandsworth - Lavender Hill (Clapham Jct)',
#                  'Species': [{'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '1',
#                               'Quality': 'Low'}]}],
#  'Westminster': [{'Site code': 'MY1',
#                   'Site name': 'Westminster - Marylebone Road',
#                   'Species': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'},
#                               {'Code': 'PM10',
#                                'Description': 'PM10 Particulate',
#                                'Index': '2',
#                                'Quality': 'Low'},
#                               {'Code': 'SO2',
#                                'Description': 'Sulphur Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'}]},
#                  {'Site code': 'MY7',
#                   'Site name': 'Westminster - Marylebone Road FDMS',
#                   'Species': [{'Code': 'PM25',
#                                'Description': 'PM2.5 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'}]},
#                  {'Site code': 'NB1',
#                   'Site name': 'Westminster - Strand (Northbank BID)',
#                   'Species': ['No species data']},
#                  {'Site code': 'WM0',
#                   'Site name': 'Westminster - Horseferry Road',
#                   'Species': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'},
#                               {'Code': 'PM10',
#                                'Description': 'PM10 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'}]},
#                  {'Site code': 'WM6',
#                   'Site name': 'Westminster - Oxford Street',
#                   'Species': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '2',
#                                'Quality': 'Low'}]},
#                  {'Site code': 'WM9',
#                   'Site name': 'Westminster - Victoria (Victoria BID)',
#                   'Species': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'}]}]}

# %%
class AirData(object):
    """Get the latest data."""

    def __init__(self):
        """Initialize the AirData object."""
        self.data = None

    def update(self):
        """Get the latest data from TFL."""
        response = requests.get(URL)
        if response.status_code != 200:
            _LOGGER.warning("Invalid response from API")
        else:
            self.data = parse_api_response(response.json())

# %%
# Class will return dict of attributes of form

attributes = {'LocalAuthorityName': 'Kingston', 
              'SiteCode': 'KT4',
              'SiteName': 'Kingston upon thames',
              '@BulletinDate': '2017-07-04 03:00:00',              # Will be sensor state
              'species': [
        {'@AirQualityBand': 'Low',
         '@AirQualityIndex': '1',
         '@IndexSource': 'Trigger',
         '@SpeciesCode': 'PM10',
         '@SpeciesName': 'PM10 Particulate'}
    ]}
