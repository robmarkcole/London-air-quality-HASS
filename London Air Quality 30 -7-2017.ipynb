# %% [markdown]
# https://www.londonair.org.uk/LondonAir/API/
#
# Docs http://api.erg.kcl.ac.uk/AirQuality/Information/Documentation/pdf

# %%
import requests
import json
import pprint

def print_json(json_data):
    pprint.PrettyPrinter().pprint(json_data)

# %% [markdown]
# # Single site - Hourly

# %%
SiteCode = 'KT4'
url = 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/SiteCode={}/Json'.format(SiteCode)
url
# Out:
# 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/SiteCode=KT4/Json'

# %%
response = requests.get(url).json()  # get the response object

# %%
print_json(response)
# Out:
# {'HourlyAirQualityIndex': {'@TimeToLive': '33',
#                            'LocalAuthority': {'@LaCentreLatitude': '51.412317',
#                                               '@LaCentreLatitudeWGS84': '6694554.466476',
#                                               '@LaCentreLongitude': '-0.300443',
#                                               '@LaCentreLongitudeWGS84': '-33445.161772',
#                                               '@LocalAuthorityCode': '21',
#                                               '@LocalAuthorityName': 'Kingston',
#                                               'Site': {'@BulletinDate': '2017-07-30 '
#                                                                         '19:00:00',
#                                                        '@Latitude': '51.379312',
#                                                        '@LatitudeWGS84': '6688665.88821522',
#                                                        '@Longitude': '-0.281259',
#                                                        '@LongitudeWGS84': '-31309.6086610253',
#                                                        '@SiteCode': 'KT4',
#                                                        '@SiteName': 'Kingston '
#                                                                     'Upon '
#                                                                     'Thames - '
#                                                                     'Tolworth '
#                                                                     'Broadway',
#                                                        '@SiteType': 'Roadside',
#                                                        'species': [{'@AirQualityBand': 'Low',
#                                                                     '@AirQualityIndex': '1',
#                                                                     '@IndexSource': 'Measurement',
#                                                                     '@SpeciesCode': 'NO2',
#                                                                     '@SpeciesName': 'Nitrogen '
#                                                                                     'Dioxide'},
#                                                                    {'@AirQualityBand': 'Low',
#                                                                     '@AirQualityIndex': '1',
#                                                                     '@IndexSource': 'Trigger',
#                                                                     '@SpeciesCode': 'PM10',
#                                                                     '@SpeciesName': 'PM10 '
#                                                                                     'Particulate'}]}}}}

# %%
base = response['HourlyAirQualityIndex']['LocalAuthority']['Site']

# %%
base['@SiteName']
# Out:
# 'Kingston Upon Thames - Tolworth Broadway'

# %%
for species in base['species']:
    print('*****')
    print(species['@SpeciesName'])
    print(species['@AirQualityIndex'])
    print(species['@AirQualityBand'])
# Out:
# *****
# Nitrogen Dioxide
# 1
# Low
# *****
# PM10 Particulate
# 1
# Low

# %% [markdown]
# # All sites - Hourly

# %%
url = 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/GroupName=London/Json'
response = requests.get(url).json()  # get the response object

# %%
base = response['HourlyAirQualityIndex']['LocalAuthority']
print(len(base))   # 33 sites
autorities_with_site = []
authorities = []

for authority in base:
    authorities.append(authority['@LocalAuthorityName'])
    if 'Site' in authority.keys():
        #print(authority['@LocalAuthorityName'])
        autorities_with_site.append(authority['@LocalAuthorityName'])
        
print(len(autorities_with_site))
print(list(set(set(authorities) - set(autorities_with_site))))
# Out:
# 33
# 28
# ['Bromley', 'Newham', 'Hounslow', 'Waltham Forest', 'Barnet']

# %%
data = {}

for authority in base:
    if authority['@LocalAuthorityName'] == 'Kingston':
        data = authority
        
data
# Out:
# {'@LaCentreLatitude': '51.412317',
#  '@LaCentreLatitudeWGS84': '6694554.466476',
#  '@LaCentreLongitude': '-0.300443',
#  '@LaCentreLongitudeWGS84': '-33445.161772',
#  '@LocalAuthorityCode': '21',
#  '@LocalAuthorityName': 'Kingston',
#  'Site': {'@BulletinDate': '2017-07-30 19:00:00',
#   '@Latitude': '51.379312',
#   '@LatitudeWGS84': '6688665.88821522',
#   '@Longitude': '-0.281259',
#   '@LongitudeWGS84': '-31309.6086610253',
#   '@SiteCode': 'KT4',
#   '@SiteName': 'Kingston Upon Thames - Tolworth Broadway',
#   '@SiteType': 'Roadside',
#   'Species': [{'@AirQualityBand': 'Low',
#     '@AirQualityIndex': '1',
#     '@IndexSource': 'Measurement',
#     '@SpeciesCode': 'NO2',
#     '@SpeciesDescription': 'Nitrogen Dioxide'},
#    {'@AirQualityBand': 'Low',
#     '@AirQualityIndex': '1',
#     '@IndexSource': 'Trigger',
#     '@SpeciesCode': 'PM10',
#     '@SpeciesDescription': 'PM10 Particulate'}]}}

# %%
# If only 1 site, then a dict is returned so wrap in a list to ensure a list ia parsed in next step
if isinstance(data['Site'], dict):
    site_data = [data['Site']]  
else:
    site_data = data['Site']  
    for site in site_data:
        print(site['@SiteName'])
        if site['Species']['@AirQualityBand'] != 'No data':      # don't print if no data
            print(site['Species']['@AirQualityBand'])
            print(site['Species']['@AirQualityIndex'])
            print(site['Species']['@SpeciesDescription'])

# %%
print(len(base[2]['Site']))   # there are 8 sites
for site in base[2]['Site']:
    print(site['@SiteName'])
# Out:
# 8
# Bexley - Belvedere West
# Bexley - Belvedere West FDMS
# Bexley - Belvedere FDMS
# Bexley - Slade Green
# Bexley - Belvedere
# Bexley - Slade Green FDMS
# Greenwich and Bexley - Falconwood FDMS
# Greenwich and Bexley - Falconwood

# %% [markdown]
# # HASS class

# %%
LOCATIONS = 'Locations'
URL = 'http://api.erg.kcl.ac.uk/AirQuality/Hourly/MonitoringIndex/GroupName=London/Json'
#SCAN_INTERVAL = timedelta(seconds=30)

# Remove authorities without any Sites ['Hounslow', 'Bromley', 'Waltham Forest', 'Barnet', 'Newham']
AUTHORITIES = [
    'Barking and Dagenham',
    'Bexley',
    'Brent',
    'Camden',
    'City of London',
    'Croydon',
    'Ealing',
    'Enfield',
    'Greenwich',
    'Hackney',
    'Hammersmith and Fulham',
    'Haringey',
    'Harrow',
    'Havering',
    'Hillingdon',
    'Islington',
    'Kensington and Chelsea',
    'Kingston',
    'Lambeth',
    'Lewisham',
    'Merton',
    'Redbridge',
    'Richmond',
    'Southwark',
    'Sutton',
    'Tower Hamlets',
    'Wandsworth',
    'Westminster']

CONFIG = {LOCATIONS: ['Merton','Richmond',]}  # A list of required locations

# %%
def parse_api_response(response):
    """Take in the API response. API can return dict or list of data so need to check. """
    data = dict.fromkeys(AUTHORITIES)     # Holds all data
    for authority in AUTHORITIES:
        for entry in response['HourlyAirQualityIndex']['LocalAuthority']:   # Loop over entries
            if entry['@LocalAuthorityName'] == authority:
                authority_data = []
                
                if isinstance(entry['Site'], dict):
                    entry_sites_data = [entry['Site']]  
                else:
                    entry_sites_data = entry['Site']  
                
                for site in entry_sites_data:
                    site_data = {}
                    species_data = []
                    
                    site_data['Site code'] = site['@SiteCode']
                    site_data['Site name'] = site['@SiteName'].split("-")[-1].lstrip()  
                    
                    if isinstance(site['Species'], dict):
                        species_data = [site['Species']]  
                    else:
                        species_data = site['Species'] 
                    
                    parsed_species_data = []
                    for species in species_data:
                        if species['@AirQualityBand'] != 'No data': 
                            species_dict = {}
                            species_dict['Description'] = species['@SpeciesDescription']
                            species_dict['Code'] = species['@SpeciesCode']
                            species_dict['Quality'] = species['@AirQualityBand']
                            species_dict['Index'] = species['@AirQualityIndex']
                            parsed_species_data.append(species_dict)
                    
                    if not parsed_species_data:      # if no valid species data
                        parsed_species_data.append('No species data')

                    site_data['Pollutants'] = parsed_species_data
                    authority_data.append(site_data)
                    
                data[authority] = authority_data

    return data

# %%
response = requests.get(URL).json()
my_data = parse_api_response(response)

# %%
my_data.keys()
# Out:
# dict_keys(['Hackney', 'Camden', 'Greenwich', 'Tower Hamlets', 'Lambeth', 'Havering', 'Kingston', 'Southwark', 'Kensington and Chelsea', 'Hillingdon', 'Sutton', 'Redbridge', 'Lewisham', 'Croydon', 'Richmond', 'Bexley', 'Haringey', 'Hammersmith and Fulham', 'Wandsworth', 'Brent', 'City of London', 'Barking and Dagenham', 'Enfield', 'Westminster', 'Harrow', 'Islington', 'Ealing', 'Merton'])

# %%
my_data['Merton']
# Out:
# [{'Pollutants': [{'Code': 'PM10',
#     'Description': 'PM10 Particulate',
#     'Index': '2',
#     'Quality': 'Low'}],
#   'Site code': 'ME2',
#   'Site name': 'Merton Road'},
#  {'Pollutants': [{'Code': 'NO2',
#     'Description': 'Nitrogen Dioxide',
#     'Index': '1',
#     'Quality': 'Low'}],
#   'Site code': 'ME9',
#   'Site name': 'Morden Civic Centre 2'}]

# %%
print_json(my_data)
# Out:
# {'Barking and Dagenham': [{'Pollutants': [{'Code': 'NO2',
#                                            'Description': 'Nitrogen Dioxide',
#                                            'Index': '1',
#                                            'Quality': 'Low'},
#                                           {'Code': 'SO2',
#                                            'Description': 'Sulphur Dioxide',
#                                            'Index': '1',
#                                            'Quality': 'Low'}],
#                            'Site code': 'BG1',
#                            'Site name': 'Rush Green'},
#                           {'Pollutants': [{'Code': 'NO2',
#                                            'Description': 'Nitrogen Dioxide',
#                                            'Index': '1',
#                                            'Quality': 'Low'},
#                                           {'Code': 'PM10',
#                                            'Description': 'PM10 Particulate',
#                                            'Index': '1',
#                                            'Quality': 'Low'}],
#                            'Site code': 'BG2',
#                            'Site name': 'Scrattons Farm'}],
#  'Bexley': [{'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'BQ7',
#              'Site name': 'Belvedere West'},
#             {'Pollutants': ['No species data'],
#              'Site code': 'BQ8',
#              'Site name': 'Belvedere West FDMS'},
#             {'Pollutants': [{'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'BX0',
#              'Site name': 'Belvedere FDMS'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '3',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'SO2',
#                              'Description': 'Sulphur Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'BX1',
#              'Site name': 'Slade Green'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'BX2',
#              'Site name': 'Belvedere'},
#             {'Pollutants': [{'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'BX9',
#              'Site name': 'Slade Green FDMS'},
#             {'Pollutants': [{'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'GB0',
#              'Site name': 'Falconwood FDMS'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'GB6',
#              'Site name': 'Falconwood'}],
#  'Brent': [{'Pollutants': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'O3',
#                             'Description': 'Ozone',
#                             'Index': '2',
#                             'Quality': 'Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'}],
#             'Site code': 'BT4',
#             'Site name': 'Ikea'},
#            {'Pollutants': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '2',
#                             'Quality': 'Low'}],
#             'Site code': 'BT5',
#             'Site name': 'Neasden Lane'},
#            {'Pollutants': [{'Code': 'NO2',
#                             'Description': 'Nitrogen Dioxide',
#                             'Index': '1',
#                             'Quality': 'Low'},
#                            {'Code': 'PM10',
#                             'Description': 'PM10 Particulate',
#                             'Index': '1',
#                             'Quality': 'Low'}],
#             'Site code': 'BT6',
#             'Site name': 'John Keble Primary School'},
#            {'Pollutants': ['No species data'],
#             'Site code': 'BT8',
#             'Site name': 'Ark Franklin Academy'}],
#  'Camden': [{'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'O3',
#                              'Description': 'Ozone',
#                              'Index': '2',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'BL0',
#              'Site name': 'Bloomsbury'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'CD1',
#              'Site name': 'Swiss Cottage'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '2',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'CD9',
#              'Site name': 'Euston Road'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'IM1',
#              'Site name': 'Holborn (inmidtown)'}],
#  'City of London': [{'Pollutants': [{'Code': 'PM25',
#                                      'Description': 'PM2.5 Particulate',
#                                      'Index': '1',
#                                      'Quality': 'Low'}],
#                      'Site code': 'CT2',
#                      'Site name': 'Farringdon Street'},
#                     {'Pollutants': [{'Code': 'PM10',
#                                      'Description': 'PM10 Particulate',
#                                      'Index': '1',
#                                      'Quality': 'Low'},
#                                     {'Code': 'PM25',
#                                      'Description': 'PM2.5 Particulate',
#                                      'Index': '1',
#                                      'Quality': 'Low'}],
#                      'Site code': 'CT3',
#                      'Site name': 'Sir John Cass School'},
#                     {'Pollutants': [{'Code': 'NO2',
#                                      'Description': 'Nitrogen Dioxide',
#                                      'Index': '1',
#                                      'Quality': 'Low'},
#                                     {'Code': 'PM10',
#                                      'Description': 'PM10 Particulate',
#                                      'Index': '1',
#                                      'Quality': 'Low'}],
#                      'Site code': 'CT4',
#                      'Site name': 'Beech Street'},
#                     {'Pollutants': [{'Code': 'NO2',
#                                      'Description': 'Nitrogen Dioxide',
#                                      'Index': '1',
#                                      'Quality': 'Low'}],
#                      'Site code': 'CT6',
#                      'Site name': 'Walbrook Wharf'},
#                     {'Pollutants': [{'Code': 'PM10',
#                                      'Description': 'PM10 Particulate',
#                                      'Index': '1',
#                                      'Quality': 'Low'}],
#                      'Site code': 'CT8',
#                      'Site name': 'Upper Thames Street'}],
#  'Croydon': [{'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'CR5',
#               'Site name': 'Norbury'},
#              {'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'CR7',
#               'Site name': 'Purley Way A23'},
#              {'Pollutants': [{'Code': 'PM25',
#                               'Description': 'PM2.5 Particulate',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'CR8',
#               'Site name': 'Norbury Manor'},
#              {'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'},
#                              {'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'CR9',
#               'Site name': 'Park Lane'}],
#  'Ealing': [{'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'EA6',
#              'Site name': 'Hanger Lane Gyratory'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'EA8',
#              'Site name': 'Horn Lane'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'EI1',
#              'Site name': 'Western Avenue'},
#             {'Pollutants': [{'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'EI8',
#              'Site name': 'Horn Lane TEOM'}],
#  'Enfield': [{'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'EN1',
#               'Site name': 'Bush Hill Park'},
#              {'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'},
#                              {'Code': 'SO2',
#                               'Description': 'Sulphur Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'EN4',
#               'Site name': 'Derby Road'},
#              {'Pollutants': [{'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'EN5',
#               'Site name': 'Bowes Primary School'},
#              {'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'EN7',
#               'Site name': 'Prince of Wales School'}],
#  'Greenwich': [{'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM25',
#                                 'Description': 'PM2.5 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'GN0',
#                 'Site name': 'A206 Burrage Grove'},
#                {'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '2',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM25',
#                                 'Description': 'PM2.5 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'GN3',
#                 'Site name': 'Plumstead High Street'},
#                {'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'GN4',
#                 'Site name': 'Fiveways Sidcup Rd A20'},
#                {'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '2',
#                                 'Quality': 'Low'},
#                                {'Code': 'SO2',
#                                 'Description': 'Sulphur Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'GR4',
#                 'Site name': 'Eltham'},
#                {'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'GR7',
#                 'Site name': 'Blackheath'},
#                {'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'GR8',
#                 'Site name': 'Woolwich Flyover'},
#                {'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '2',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM25',
#                                 'Description': 'PM2.5 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'GR9',
#                 'Site name': 'Westhorne Avenue'}],
#  'Hackney': [{'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'},
#                              {'Code': 'O3',
#                               'Description': 'Ozone',
#                               'Index': '2',
#                               'Quality': 'Low'},
#                              {'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'HK6',
#               'Site name': 'Old Street'}],
#  'Hammersmith and Fulham': [{'Pollutants': [{'Code': 'NO2',
#                                              'Description': 'Nitrogen Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low'},
#                                             {'Code': 'PM10',
#                                              'Description': 'PM10 Particulate',
#                                              'Index': '1',
#                                              'Quality': 'Low'}],
#                              'Site code': 'HF4',
#                              'Site name': 'Shepherds Bush'}],
#  'Haringey': [{'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'HG1',
#                'Site name': 'Haringey Town Hall'},
#               {'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'},
#                               {'Code': 'O3',
#                                'Description': 'Ozone',
#                                'Index': '2',
#                                'Quality': 'Low'}],
#                'Site code': 'HG4',
#                'Site name': 'Priory Park South'}],
#  'Harrow': [{'Pollutants': ['No species data'],
#              'Site code': 'HR1',
#              'Site name': 'Stanmore'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'HR2',
#              'Site name': 'Pinner Road'}],
#  'Havering': [{'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'HV1',
#                'Site name': 'Rainham'},
#               {'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'},
#                               {'Code': 'PM10',
#                                'Description': 'PM10 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'HV3',
#                'Site name': 'Romford'}],
#  'Hillingdon': [{'Pollutants': [{'Code': 'NO2',
#                                  'Description': 'Nitrogen Dioxide',
#                                  'Index': '1',
#                                  'Quality': 'Low'},
#                                 {'Code': 'O3',
#                                  'Description': 'Ozone',
#                                  'Index': '2',
#                                  'Quality': 'Low'}],
#                  'Site code': 'HI0',
#                  'Site name': 'Keats Way'},
#                 {'Pollutants': ['No species data'],
#                  'Site code': 'LH0',
#                  'Site name': 'Harlington'}],
#  'Islington': [{'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'IS2',
#                 'Site name': 'Holloway Road'},
#                {'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'IS6',
#                 'Site name': 'Arsenal'}],
#  'Kensington and Chelsea': [{'Pollutants': [{'Code': 'NO2',
#                                              'Description': 'Nitrogen Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low'},
#                                             {'Code': 'O3',
#                                              'Description': 'Ozone',
#                                              'Index': '3',
#                                              'Quality': 'Low'},
#                                             {'Code': 'SO2',
#                                              'Description': 'Sulphur Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low'}],
#                              'Site code': 'KC1',
#                              'Site name': 'North Ken'},
#                             {'Pollutants': [{'Code': 'NO2',
#                                              'Description': 'Nitrogen Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low'},
#                                             {'Code': 'PM10',
#                                              'Description': 'PM10 Particulate',
#                                              'Index': '1',
#                                              'Quality': 'Low'},
#                                             {'Code': 'PM25',
#                                              'Description': 'PM2.5 Particulate',
#                                              'Index': '1',
#                                              'Quality': 'Low'}],
#                              'Site code': 'KC2',
#                              'Site name': 'Cromwell Road'},
#                             {'Pollutants': [{'Code': 'NO2',
#                                              'Description': 'Nitrogen Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low'}],
#                              'Site code': 'KC3',
#                              'Site name': 'Knightsbridge'},
#                             {'Pollutants': [{'Code': 'NO2',
#                                              'Description': 'Nitrogen Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low'}],
#                              'Site code': 'KC4',
#                              'Site name': 'Kings Road'},
#                             {'Pollutants': [{'Code': 'NO2',
#                                              'Description': 'Nitrogen Dioxide',
#                                              'Index': '1',
#                                              'Quality': 'Low'}],
#                              'Site code': 'KC5',
#                              'Site name': 'Earls Court Rd'},
#                             {'Pollutants': ['No species data'],
#                              'Site code': 'KC7',
#                              'Site name': 'North Ken FDMS'}],
#  'Kingston': [{'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'},
#                               {'Code': 'PM10',
#                                'Description': 'PM10 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'KT4',
#                'Site name': 'Tolworth Broadway'}],
#  'Lambeth': [{'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '2',
#                               'Quality': 'Low'},
#                              {'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '2',
#                               'Quality': 'Low'}],
#               'Site code': 'LB4',
#               'Site name': 'Brixton Road'},
#              {'Pollutants': [{'Code': 'NO2',
#                               'Description': 'Nitrogen Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'},
#                              {'Code': 'PM10',
#                               'Description': 'PM10 Particulate',
#                               'Index': '3',
#                               'Quality': 'Low'},
#                              {'Code': 'SO2',
#                               'Description': 'Sulphur Dioxide',
#                               'Index': '1',
#                               'Quality': 'Low'}],
#               'Site code': 'LB5',
#               'Site name': 'Bondway Interchange'},
#              {'Pollutants': ['No species data'],
#               'Site code': 'LB6',
#               'Site name': 'Streatham Green'}],
#  'Lewisham': [{'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'LW1',
#                'Site name': 'Catford'},
#               {'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'},
#                               {'Code': 'PM10',
#                                'Description': 'PM10 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'},
#                               {'Code': 'PM25',
#                                'Description': 'PM2.5 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'LW2',
#                'Site name': 'New Cross'},
#               {'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'},
#                               {'Code': 'PM10',
#                                'Description': 'PM10 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'LW4',
#                'Site name': 'Loampit Vale'}],
#  'Merton': [{'Pollutants': [{'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '2',
#                              'Quality': 'Low'}],
#              'Site code': 'ME2',
#              'Site name': 'Merton Road'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'ME9',
#              'Site name': 'Morden Civic Centre 2'}],
#  'Redbridge': [{'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'RB4',
#                 'Site name': 'Gardner Close'},
#                {'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '2',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM25',
#                                 'Description': 'PM2.5 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'RB7',
#                 'Site name': 'Ley Street'}],
#  'Richmond': [{'Pollutants': ['No species data'],
#                'Site code': 'RHG',
#                'Site name': 'Chertsey Road'},
#               {'Pollutants': [{'Code': 'PM10',
#                                'Description': 'PM10 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'RI1',
#                'Site name': 'Castelnau'},
#               {'Pollutants': [{'Code': 'NO2',
#                                'Description': 'Nitrogen Dioxide',
#                                'Index': '1',
#                                'Quality': 'Low'},
#                               {'Code': 'O3',
#                                'Description': 'Ozone',
#                                'Index': '2',
#                                'Quality': 'Low'},
#                               {'Code': 'PM10',
#                                'Description': 'PM10 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'RI2',
#                'Site name': 'Barnes Wetlands'},
#               {'Pollutants': ['No species data'],
#                'Site code': 'TD0',
#                'Site name': 'Ntl Physical  Lab'},
#               {'Pollutants': [{'Code': 'PM25',
#                                'Description': 'PM2.5 Particulate',
#                                'Index': '1',
#                                'Quality': 'Low'}],
#                'Site code': 'TD5',
#                'Site name': 'Bushy Park'}],
#  'Southwark': [{'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'SK5',
#                 'Site name': 'A2 Old Kent Road'},
#                {'Pollutants': [{'Code': 'NO2',
#                                 'Description': 'Nitrogen Dioxide',
#                                 'Index': '1',
#                                 'Quality': 'Low'},
#                                {'Code': 'O3',
#                                 'Description': 'Ozone',
#                                 'Index': '2',
#                                 'Quality': 'Low'},
#                                {'Code': 'PM10',
#                                 'Description': 'PM10 Particulate',
#                                 'Index': '1',
#                                 'Quality': 'Low'}],
#                 'Site code': 'SK6',
#                 'Site name': 'Elephant and Castle'}],
#  'Sutton': [{'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'ST4',
#              'Site name': 'Wallington'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM25',
#                              'Description': 'PM2.5 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'ST5',
#              'Site name': 'Beddington Lane north'},
#             {'Pollutants': [{'Code': 'NO2',
#                              'Description': 'Nitrogen Dioxide',
#                              'Index': '1',
#                              'Quality': 'Low'},
#                             {'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'ST6',
#              'Site name': 'Worcester Park'},
#             {'Pollutants': [{'Code': 'PM10',
#                              'Description': 'PM10 Particulate',
#                              'Index': '1',
#                              'Quality': 'Low'}],
#              'Site code': 'ST8',
#              'Site name': 'Beddington Lane'}],
#  'Tower Hamlets': [{'Pollutants': [{'Code': 'NO2',
#                                     'Description': 'Nitrogen Dioxide',
#                                     'Index': '1',
#                                     'Quality': 'Low'}],
#                     'Site code': 'TH2',
#                     'Site name': 'Mile End Road'},
#                    {'Pollutants': [{'Code': 'NO2',
#                                     'Description': 'Nitrogen Dioxide',
#                                     'Index': '1',
#                                     'Quality': 'Low'},
#                                    {'Code': 'O3',
#                                     'Description': 'Ozone',
#                                     'Index': '2',
#                                     'Quality': 'Low'},
#                                    {'Code': 'PM10',
#                                     'Description': 'PM10 Particulate',
#                                     'Index': '1',
#                                     'Quality': 'Low'},
#                                    {'Code': 'PM25',
#                                     'Description': 'PM2.5 Particulate',
#                                     'Index': '1',
#                                     'Quality': 'Low'}],
#                     'Site code': 'TH4',
#                     'Site name': 'Blackwall'}],
#  'Wandsworth': [{'Pollutants': [{'Code': 'NO2',
#                                  'Description': 'Nitrogen Dioxide',
#                                  'Index': '1',
#                                  'Quality': 'Low'}],
#                  'Site code': 'WA2',
#                  'Site name': 'Wandsworth Town Hall'},
#                 {'Pollutants': [{'Code': 'PM10',
#                                  'Description': 'PM10 Particulate',
#                                  'Index': '1',
#                                  'Quality': 'Low'}],
#                  'Site code': 'WA7',
#                  'Site name': 'Putney High Street'},
#                 {'Pollutants': ['No species data'],
#                  'Site code': 'WA8',
#                  'Site name': 'Putney High Street Facade'},
#                 {'Pollutants': ['No species data'],
#                  'Site code': 'WA9',
#                  'Site name': 'Putney'},
#                 {'Pollutants': ['No species data'],
#                  'Site code': 'WAA',
#                  'Site name': 'Battersea'},
#                 {'Pollutants': [{'Code': 'PM10',
#                                  'Description': 'PM10 Particulate',
#                                  'Index': '1',
#                                  'Quality': 'Low'}],
#                  'Site code': 'WAB',
#                  'Site name': 'Tooting High Street'},
#                 {'Pollutants': [{'Code': 'PM10',
#                                  'Description': 'PM10 Particulate',
#                                  'Index': '1',
#                                  'Quality': 'Low'}],
#                  'Site code': 'WAC',
#                  'Site name': 'Lavender Hill (Clapham Jct)'}],
#  'Westminster': [{'Pollutants': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low'},
#                                  {'Code': 'PM10',
#                                   'Description': 'PM10 Particulate',
#                                   'Index': '2',
#                                   'Quality': 'Low'},
#                                  {'Code': 'SO2',
#                                   'Description': 'Sulphur Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low'}],
#                   'Site code': 'MY1',
#                   'Site name': 'Marylebone Road'},
#                  {'Pollutants': [{'Code': 'PM25',
#                                   'Description': 'PM2.5 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low'}],
#                   'Site code': 'MY7',
#                   'Site name': 'Marylebone Road FDMS'},
#                  {'Pollutants': ['No species data'],
#                   'Site code': 'NB1',
#                   'Site name': 'Strand (Northbank BID)'},
#                  {'Pollutants': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low'},
#                                  {'Code': 'PM10',
#                                   'Description': 'PM10 Particulate',
#                                   'Index': '1',
#                                   'Quality': 'Low'}],
#                   'Site code': 'WM0',
#                   'Site name': 'Horseferry Road'},
#                  {'Pollutants': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '2',
#                                   'Quality': 'Low'}],
#                   'Site code': 'WM6',
#                   'Site name': 'Oxford Street'},
#                  {'Pollutants': [{'Code': 'NO2',
#                                   'Description': 'Nitrogen Dioxide',
#                                   'Index': '1',
#                                   'Quality': 'Low'}],
#                   'Site code': 'WM9',
#                   'Site name': 'Victoria (Victoria BID)'}]}

# %%
class AirData(object):
    """Get the latest data."""

    def __init__(self):
        """Initialize the AirData object."""
        self.data = None

    def update(self):
        """Get the latest data from TFL."""
        response = requests.get(URL)
        if response.status_code != 200:
            _LOGGER.warning("Invalid response from API")
        else:
            self.data = parse_api_response(response.json())

# %%
# Class will return dict of attributes of form

attributes = {'LocalAuthorityName': 'Kingston', 
              'SiteCode': 'KT4',
              'SiteName': 'Kingston upon thames',
              '@BulletinDate': '2017-07-04 03:00:00',              # Will be sensor state
              'species': [
        {'@AirQualityBand': 'Low',
         '@AirQualityIndex': '1',
         '@IndexSource': 'Trigger',
         '@SpeciesCode': 'PM10',
         '@SpeciesName': 'PM10 Particulate'}
    ]}
